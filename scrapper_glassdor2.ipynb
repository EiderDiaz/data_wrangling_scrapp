# %%
from selenium import webdriver
import sys
import time
#sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import pandas as pd

# %% [markdown]
# ### setup
# antes de correr debes descargar el chrome driver acorde a tu maquina
# https://sites.google.com/chromium.org/driver/downloads

# %% [markdown]
# ### helper functions

# %%
def init_scrapper(keyword="data science", headless = False ):
    """"initialize the glassdor scrapper given a job keyword"""
    # Initializing the webdriver
    options = webdriver.ChromeOptions()

    #Uncomment the line below if you'd like to scrape without a new Chrome window every time.
    if headless: options.add_argument('headless')

    #Change the path to where chromedriver is in your home folder.
    #driver = webdriver.Chrome(executable_path=driverpath, options=options)

    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    url = "https://www.glassdoor.com/Job/jobs.htm?suggestCount=0&suggestChosen=false&clickSource=searchBtn&typedKeyword="+keyword+"&sc.keyword="+keyword+"&locT=&locId=&jobType="
    driver.get(url)

    return driver


def get_companyname_rating(company_name):
    """gets the company name and (if exist) gets the company rating too"""
    splited = company_name.split("\n")
    #company name comes with rating 
    if len(splited) > 1:
        return splited[0],  splited[1]
    #just company name
    else:
        return company_name, -1


def get_company_overview_data(Company_Overview):
    """"gets the company overview data (dont the name of the func speaks for itself?)"""
    Company_Overview_dict = {"size":"",
                            "founded":"",
                            "type":"",
                            "industry":"",
                            "sector":"",
                            "revenue":"",}

    for i, key in enumerate(Company_Overview_dict):
        try: 
            Company_Overview_dict[key] = Company_Overview[i].text
        except:
            print(f"{key} not found")
            Company_Overview_dict[key] = -1
    return Company_Overview_dict


def response_to_dataframe(list_of_dicts,filename):
  """cast list of dict into df, if filename is specified exports the csv """
  df = pd.DataFrame(list_of_dicts)
  if filename:
    df.to_csv(f'./{filename}.csv')
  return df

# %%
#path = ""
keyword = "data science"
init_scrapper(keyword)

# %% [markdown]
# ### SCRAPPER

# %%
def get_jobs(keyword, num_jobs, verbose, slp_time, failsafe = False):
    
    """Gathers jobs as a dataframe, scraped from Glassdoor"""
    driver = init_scrapper(keyword)
    jobs = []
    #Let the page load. Change this number based on your internet speed.
    time.sleep(2*slp_time)
    while len(jobs) < num_jobs:  #If true, should be still looking for new jobs.

        #Going through each job in this page
        job_buttons = driver.find_elements(By.CLASS_NAME, "react-job-listing")  #react-job-listing for Job Listing. These are the buttons we're going to click.
        print(f"size job buttons {len(job_buttons)}")
        for job_button in job_buttons:  

            print(f"Progress:  {len(jobs)}/{ num_jobs}")
            if len(jobs) >= num_jobs:
                break
            job_button.click()  #You might 
            time.sleep(slp_time)
            # Test for the "Sign Up" prompt and get rid of it.
            # close modal (just appear on the first pass)
            if len(jobs) == 0:
                try:
                    driver.find_element(By.XPATH, '//*[@id="JAModal"]/div/div[2]/span').click()
                    #driver.find_element(By.CLASS_NAME,'modal_closeIcon').click()
                    print("modal cerrado con exito")
                except NoSuchElementException:
                    print("no hay modal xd")
                    
            collected_successfully = False
            while not collected_successfully:
                try:

                    company_name_ = driver.find_element(By.CLASS_NAME, 'e1tk4kwz5').text
                    #sometimes company name comes with the rating, if its the case get_companyname_rating handles it
                    company_name, rating = get_companyname_rating(company_name_) 
                    location = driver.find_element(By.CLASS_NAME,'e1tk4kwz1').text
                    job_title = driver.find_element(By.CLASS_NAME,'e1tk4kwz2').text
                    job_description = driver.find_element(By.XPATH,'.//div[@class="jobDescriptionContent desc"]').text
                    salary_estimate = driver.find_element(By.CLASS_NAME,'e2u4hf18').text if driver.find_element(By.CLASS_NAME,'e2u4hf18') else "N/A"
                    collected_successfully = True
                    print("job info collected successfully :)")
                except:
                    time.sleep(slp_time/2)
                    print("job info error, trying again...")
                    break

            job_data_dict = {"Job Title" : job_title,
                            "Company Name" : company_name,
                            "Location" : location,
                            "Salary Estimate" : salary_estimate,
                            "Rating" : rating,
                            "Job Description" : job_description,
                        }

            #Printing for debugging
            if verbose:
                print(job_data_dict)

            #Going to the Company tab...
            #clicking on this:
            #<div class="tab" data-tab-type="overview"><span>Company</span></div>
            try:
                Company_Overview = driver.find_elements(By.CLASS_NAME,'e1pvx6aw0')
                company_overview_dict = get_company_overview_data(Company_Overview)

            except NoSuchElementException:  #Rarely, some job postings do not have the "Company" tab.
                company_overview_dict = {"size":-1,
                                        "founded":-1,
                                        "type":-1,
                                        "industry":-1,
                                        "sector":-1,
                                        "revenue":-1}
                
            if verbose:
                print(company_overview_dict)
                print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
            
            job_data_dict.update(company_overview_dict)

            jobs.append(job_data_dict)
            if failsafe: response_to_dataframe(jobs,"jobs_df")

            #add job to jobs
            
            
        #Clicking on the "next page" button
        try:
            driver.find_element(By.CLASS_NAME,'nextButton').click()
            time.sleep(slp_time/2)
        except NoSuchElementException:
            print("Scraping terminated before reaching target number of jobs. Needed {}, got {}.".format(num_jobs, len(jobs)))
            break
        
    driver.close()
    return pd.DataFrame(jobs)  #This line converts the dictionary object into a pandas DataFrame.

# %%
# https://stackoverflow.com/questions/60362018/macos-catalinav-10-15-3-error-chromedriver-cannot-be-opened-because-the-de
#path = "/opt/homebrew/bin/chromedriver"
keyword = "data science"
num_jobs = 30
slp_time = 6
verbose = True
failsafe = True

df = get_jobs(keyword, num_jobs, verbose, slp_time,failsafe)
df
# Out:
# size job buttons 30
# Progress:  0/30
# modal cerrado con exito
# job info collected successfully :)
# {'Job Title': 'Junior Data Scientist', 'Company Name': 'Talentheed Inc', 'Location': 'Remote', 'Salary Estimate': '$100,000 /yr (est.)', 'Rating': -1, 'Job Description': 'Responsibilities:\nWork with stakeholders to determine how to use business data for valuable business solutions.\nSearch for ways to get new data sources and assess their accuracy.\nBrowse and analyze enterprise databases to simplify and improve product development, marketing techniques, and business processes.\nCreate custom data models and algorithms.\nUse predictive models to improve customer experience, ad targeting, revenue generation, and more.\nDevelop the organization’s test model quality and A/B testing framework.\nCoordinate with various technical/functional teams to implement models and monitor results.'}
# size not found
# founded not found
# type not found
# industry not found
# sector not found
# revenue not found
# {'size': -1, 'founded': -1, 'type': -1, 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  1/30
# job info collected successfully :)
# {'Job Title': 'Mgr Data Science', 'Company Name': 'South West', 'Location': 'Dallas, TX', 'Salary Estimate': '$103,267 /yr (est.)', 'Rating': '4.2', 'Job Description': "Department: Business Transformation\n\nOur Company Promise\n\nWe are committed to provide our Employees a stable work environment with equal opportunity for learning and personal growth. Creativity and innovation are encouraged for improving the effectiveness of Southwest Airlines. Above all, Employees will be provided the same concern, respect, and caring attitude within the organization that they are expected to share externally with every Southwest Customer.\n\nJob Description:\nJob Summary\nManages Performance and Work initiatives of a Team of 4-6 professional employees, typically focusing on 50% Leadership and 50% Management. Sets strategy for Team in support of Departmental strategy. Applies knowledge of unique and non-repetitive type work. Contributes to projects and cross functional initiatives; identifies talent and builds bench. A Manager of Data Science in Southwest Airlines' Corporate Strategy Department serves as a leader of the data science practice, responsible for a Team of data scientists, data engineering consultants, and advisors tasked with creating innovative data science solutions and integrated data assets across the Company as well as developing and maturing the discipline of data science so that it is a competitive advantage for the Company.\nResponsibilities\nDevelops and effectively communicates a vision for the Data Science Center and community, long-term and near-term plans necessary to meet the vision, and a roadmap necessary to execute long-term and near-term plans\nEffectively coordinates and manages the Team in alignment with overall plans\nEffectively manages skills and training necessary to execute on long-term and near-term plans\nIdentifies and evaluates the most important opportunities and issues across the enterprise to be addressed through data science and works with leadership to manage those opportunities\nServes as leader, advisor, or mentor on multiple, highly complex data science programs, working with business Customers to understand contextual problems quickly and define, analyze, and deliver innovative solutions based on business objectives\nRecognized as a subject matter expert on data science methodologies and tools\nLeads others on the application of mathematics, statistic, and/or advanced modeling methods to discover and gain insights on business problems; create, monitor, and manage entities; and/or develop predictive or prescriptive capabilities in creative ways\nAdvises with functional, senior, and executive leaders across multiple and concurrent projects\nLeads the formulation of solutions and communicates those solutions and options for highly complex problems\nLeads the creation and communication of results from highly complex data analysis and models\nLeads the Team's efforts to manage the ongoing effectiveness of a network of models in use by business Customer\nMust be able to meet any physical ability requirements listed on this description\nMay perform other job duties as directed by Employee's Leaders\nKnowledge, Skills and Abilities\nDevelop People\nDemonstrates self-confidence in crucial conversations that result in positive action or change\nProvides direction, when needed, without micromanaging; allows opportunity to learn from mistakes\nAsks questions to challenge Employees assumptions, elicit new insights, raise self-awareness, and gain learning\nShows the Employee where habits are holding them back and supports any change necessary\nLooks for and develops talent, proactively; able to replace people in key positions across functional area\nMaintains transparency by ensuring high potential individuals know where they are on the succession plan\nThink Strategically\nAnticipates changing circumstances, unexpected constraints or challenges\nDevelops ideas, processes, and approaches to meet future  ...
# {'size': '10000+ Employees', 'founded': '1967', 'type': 'Company - Public', 'industry': 'Airlines, Airports & Air Transportation', 'sector': 'Transportation & Logistics', 'revenue': '$10+ billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  2/30
# job info error, trying again...
# {'Job Title': 'Junior Data Analyst', 'Company Name': 'Human Exponent Inc.', 'Location': 'Remote', 'Salary Estimate': '$103,267 /yr (est.)', 'Rating': '5.0', 'Job Description': "We are seeking a highly motivated analyst to join our Client’s cross-commodities research business providing clarity on the fuel market economy in a time of unprecedented uncertainty in the energy markets. Demonstrating passion and curiosity, you will be excited by the responsibility of developing industry-leading data and analysis to drive insight into fuel fundamentals and their impact on World's energy markets, supporting decision making in an increasingly important sector.\nIf you have:\nAPPLY HERE: https://www.gyfted.me/job-offer/gyfted-junior_data_analyst\nHigher education in a numerical subject (data science, econometrics, physics, industrial mathematics, computer science/artificial statistics, applied physics, economic, meteorology, engineering ) or demonstration of practical experience in a role where there was a quantitative focus\nStrong analytical and quantitative skills"}
# industry not found
# sector not found
# revenue not found
# {'size': '1 to 50 Employees', 'founded': 'Company - Private', 'type': 'Unknown / Non-Applicable', 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  3/30
# job info collected successfully :)
# {'Job Title': 'Gcp data engineer', 'Company Name': 'Infinity Quest', 'Location': 'Remote', 'Salary Estimate': '$100.00 /hr (est.)', 'Rating': '4.3', 'Job Description': 'Hello ,\nGood day,\nInfinity Quest is seeking an opportunity GCP Engineer with a client located in Irvine, CA (Remote).\nWe hope this Job meets your skills and expectations. If you are available and interested, please contact me at your earliest convenience. You will be working with a highly skilled team of IT Professionals in a high pace corporate environment. This opportunity will move quickly and candidates will be interviewed in the order they apply.\nRole: GCP Engineer\nLocation: Irvine, CA (Remote)'}
# {'size': '201 to 500 Employees', 'founded': '2006', 'type': 'Company - Private', 'industry': 'Information Technology Support Services', 'sector': 'Information Technology', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  4/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist - Personalization', 'Company Name': 'Audible', 'Location': 'Newark, NJ', 'Salary Estimate': '$85,503 /yr (est.)', 'Rating': '4.0', 'Job Description': "Job summary\nGood storytelling starts with great listening. At Audible, that means each role and every project has our audience in mind. Because the same people who design, develop, and deploy our products also happen to use them. To us, that speaks volumes.\n\nABOUT THE ROLE\nHey – there’s a revolution going on! A revolution in digital entertainment. Every day millions of people around the world choose to be more thoughtfully entertained, informed and educated by listening to fascinating stories and all forms of fictional and non-fictional content. Want to shape the future of this innovation through statistics and machine learning? If so, this may be a great fit for you!\n\nAs Data Scientist - Personalization, you will make the best of your skillset in predictive modeling to explain, quantify, predict and prescribe in support of informing critical business decisions. You will translate business goals into agile, insightful analytics. You will seek to create value for both stakeholders and customers, and will inform findings in a clear, actionable way to managers and senior leaders.\n\nABOUT THE TEAM\nThe Audible Data Science Team partners with marketing, content, product, and technology partners to solve business and technology problems using scientific approaches to build product and services that surprise and delight our customers. We employ scalable cutting-edge machine learning (ML), deep learning (DL), and Natural Language Processing (NLP) knowledge to better target customers and prospects, understand and personalize the content, and context needed to optimize their book-listening experience. We operate in an agile environment in which we own and collaborate on the life cycle of research, design, and model development of relevant projects.\n\nWe are looking for motivated, results-oriented Data Scientist with strong rigor and demonstrable skills in Machine Learning, Deep Learning, Natural Language Processing, data mining and/or large-scale distributed computation.\n\nAs a Data Scientist - Personalization, you will...\n\nBasic Qualifications\n\nPreferred Qualifications\n\nABOUT AUDIBLE\nAt Audible, we innovate and inspire through the power of voice. We're changing the narrative on storytelling. As a leading creator and provider of premium audio storytelling, we've redefined the ways people access, discover, and share stories. The stories we tell have the ability to transport and transform everyday moments into meaningful experiences and it's our people who make Audible's service possible. We're listeners, storytellers, and problem-solvers. Our perspectives and experiences power our ideas and come together in our mission to unleash the power of the spoken word. Audible offers a Hub+Home hybrid workplace model that gives employees flexibility between gathering in a common office space (work from hub) and remote work (work from home). Some teams will work mostly at hub, some mostly at home and others hybrid. For more information, please visit adbl.co/hybrid.\n\nAudible is committed to a diverse and inclusive workplace. Audible is an equal opportunity employer and does not discriminate on the basis of race, national origin, gender, gender identity, sexual orientation, protected veteran status, disability, age, or other legally protected status. For individuals with disabilities who would like to request an accommodation, please visit https://www.amazon.jobs/en/disability/us."}
# {'size': '1001 to 5000 Employees', 'founded': '1995', 'type': 'Subsidiary or Business Segment', 'industry': 'Film Production', 'sector': 'Media & Communication', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  5/30
# job info collected successfully :)
# {'Job Title': 'Jr. Data Analyst', 'Company Name': 'PepsiCo', 'Location': 'Chicago, IL', 'Salary Estimate': '$57,332 /yr (est.)', 'Rating': '3.9', 'Job Description': "This position can be located in Plano, Texas - Purchase, New York, - Chicago, Illinois\nJob Description\nAs a Data Analyst, you will be the key domain expert overseeing PepsiCo's business process and drive a strong discussion for how Supply Chain, Financial, Consumer, Channel, Category business needs to be defined and prioritize by working very closely with business leads, data science team and data engineering team. You'll develop an in-depth understanding of business processes in and translate business requirements to data engineering team in technical way.\nAccountabilities:\nDiscover, analyze, and scope data requirements & representing them in conceptual and logical data models"}
# {'size': '10000+ Employees', 'founded': '1965', 'type': 'Company - Public', 'industry': 'Food & Beverage Manufacturing', 'sector': 'Manufacturing', 'revenue': '$10+ billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  6/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist', 'Company Name': 'IV IT Solutions', 'Location': 'Remote', 'Salary Estimate': '$82.50 /hr (est.)', 'Rating': '5.0', 'Job Description': "Hello,\nHope you are doing great!\nThis is james from IV IT Solutions.We've immediate requirements for the following position. If you are interested, Please reply back or reach me on (571)-748-4811\nJob Title: Data Scientist\nLocation: 100% Remote\nDuration: 12+ Months\nClient Expectation:\nStrong Python coding (Mandatory)\ngood understanding of data and statistics"}
# industry not found
# sector not found
# revenue not found
# {'size': '1 to 50 Employees', 'founded': 'Company - Private', 'type': 'Unknown / Non-Applicable', 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  7/30
# job info collected successfully :)
# {'Job Title': 'Data Science Assistant', 'Company Name': 'United Nations', 'Location': 'New York, NY', 'Salary Estimate': '$88,585 /yr (est.)', 'Rating': '4.0', 'Job Description': 'This position is located in the Analytics Section of the Analytics and Project Management Service of the Business Transformation and Accountability Division (BTAD) in the Department of Management Strategy, Policy and Compliance (DMSPC). The incumbent reports to a Data Scientist.\n\nFor more information, please visit https://www.un.org/management/content/our-offices.\nResponsibilities\nWithin delegated authority, the Data Science Assistant will be responsible for the following duties:\n\nAssists with the preparation of input for response to requests for exploration, identification, and acquisition of data sources to determine their suitability for use in decision making and advancing the goals of the organization.\nCompetencies\n\n\n\nEducation\nWork Experience\n\n\n\n\n\n\n\n\nLanguages\nAssessment\nSpecial Notice\n\n\n\n\n\n\nUnited Nations Considerations\n\n\n\n\n\n\n\n\n\n\nNo Fee'}
# {'size': '10000+ Employees', 'founded': '1945', 'type': 'Government', 'industry': 'National Agencies', 'sector': 'Government & Public Administration', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  8/30
# job info collected successfully :)
# {'Job Title': 'Data Annotator', 'Company Name': 'Skit.ai', 'Location': 'New York, NY', 'Salary Estimate': '$46,817 /yr (est.)', 'Rating': '4.5', 'Job Description': 'About us\nSkit (previously known as Vernacular.ai) is an AI-first SaaS voice automation company. Its suite of speech and language solutions enable enterprises to automate their contact centre operations. With over 10 million hours of training data, its product - Vernacular Intelligent Voice Assistant (VIVA) can currently respond in 16+ languages, covering over 160+ dialects and replicating human-like conversations.\n\nSkit currently serves a variety of enterprise clients across diverse sectors such as BFSI, F&B, Hospitality, Consumer Electronics and Travel & Tourism, including prominent clients like Axis Bank, Hathway, Porter and Barbeque Nation. It has been featured as one of the top-notch start-ups in the Cisco Launchpad’s Cohort 6 and is a part of the World Economic Forum’s Global Innovators Community. It has has also been listed in Forbes 30 Under 30 Asia start-ups 2021 for its remarkable industry innovation.'}
# {'size': '51 to 200 Employees', 'founded': '2016', 'type': 'Company - Private', 'industry': 'Enterprise Software & Network Solutions', 'sector': 'Information Technology', 'revenue': '$1 to $5 million (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  9/30
# job info error, trying again...
# {'Job Title': 'Data Science and Signal Engineer I', 'Company Name': 'Medtronic', 'Location': 'Northridge, CA', 'Salary Estimate': '$46,817 /yr (est.)', 'Rating': '4.1', 'Job Description': 'Careers that Change Lives\nEngineers create our market-leading portfolio of innovations. Combine the best of your experience with training and mentorship to move forward. If you want a challenging, energizing, rewarding career that changes lives, join us. Help us bring the next generation of life-changing medical technology to patients worldwide.\n\nA Day in the Life\nWe are looking for an enthusiastic individual with strong analytical skills to join our algorithm development and data analytics team at Medtronic Diabetes (Northridge, CA). The position involves the support of research and development of medical devices related to continuous glucose monitors. The individual will work with members of research staff to improve the performance of continuous glucose sensors through the application of machine learning, analytics, signal processing and mathematical modeling and experimentation. The role will involve all aspects of the research process, including data processing, analysis, theory development and validation.'}
# {'size': '10000+ Employees', 'founded': '1949', 'type': 'Company - Public', 'industry': 'Health Care Products Manufacturing', 'sector': 'Manufacturing', 'revenue': '$10+ billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  10/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist', 'Company Name': 'Infologitech', 'Location': 'Remote', 'Salary Estimate': '$85.00 /hr (est.)', 'Rating': '4.3', 'Job Description': "Qualifications:\n-10+ years experience with R, SQL, Python, or other data science programming languages; OR Master's/PhD degree and 5+ years experience\nSkills\nData science, artificial intelligence and machine learning projects Required 3 Years\nData Analysis Tools - Python, R, RStudio, Jupyter Notebooks, SQL, Tableau Required 3 Years\nBuilding and Training Machine Learning Models Required 3 Years\nDatabase management Nice to have 3 Years\nLead the discussions with business stakeholders to design appropriate model specifications to solve business problems; Highly desired 3 Years"}
# revenue not found
# {'size': '1 to 50 Employees', 'founded': 'Company - Private', 'type': 'Information Technology Support Services', 'industry': 'Information Technology', 'sector': '$1 to $5 million (USD)', 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  11/30
# job info collected successfully :)
# {'Job Title': 'Data Science- Database/Applications Analyst', 'Company Name': 'Salud Revenue Partners', 'Location': 'Remote', 'Salary Estimate': '$52,000 /yr (est.)', 'Rating': '4.5', 'Job Description': 'Salud Revenue Partners (Salud) is a technology-enabled service company with experienced leadership and a high-performance culture that partners with healthcare providers to improve revenue cycle performance.\nOur vision is to be a national model for the delivery of revenue cycle services. We are at the forefront of innovation, applying next-generation process automation and artificial intelligence to focus on the most productive work to help healthcare organizations resolve difficult accounts receivable, find gold in zero balance accounts, achieve the highest coding accuracy and carry out patient-centered solutions to self-pay.\nAt Salud Revenue Partners, you can work for an organization dedicated to your employee development as well as delivering unparalleled results for our customers. We give staff objectives, exceptional training and technology-enabled resources to accomplish goals – and then set them free to get the job done. We encourage fresh ideas and a collaborative approach to delivering industry-leading solutions to clients.'}
# {'size': '51 to 200 Employees', 'founded': '2011', 'type': 'Company - Private', 'industry': 'HR Consulting', 'sector': 'Human Resources & Staffing', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  12/30
# job info collected successfully :)
# {'Job Title': 'Data Science Engineer - (Day-1 Onsite w/ Flexible WFH Option)', 'Company Name': 'Serve Professionals', 'Location': 'San Antonio, TX', 'Salary Estimate': '$110,000 /yr (est.)', 'Rating': '2.4', 'Job Description': 'Data Science Engineer - (Day-1 Onsite w/ Flexible WFH Option)\nSan Antonio, TX\nFull-Time (W2)\n*\nSalary: 100K and above, depending on experience\nExperience: 6 to 7 years\n*\n*\nJob Description\nAs a Senior Data Scientist, your archetype is a Business Decision Scientist. Your passions include building a framework to stitch cross domains learning and optimizing them toward mission-specific and multi-mission tasks, uncovering ML models causality relationships, creating an enterprise domain-specific reasoning system to boost actionable insights and optimize resources of the machine learning process, and orchestrating reusable storytelling methodology to apply toward AI translation.\n*\n*\nWhat is the work?'}
# industry not found
# sector not found
# revenue not found
# {'size': 'Unknown', 'founded': 'Company - Public', 'type': 'Unknown / Non-Applicable', 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  13/30
# job info collected successfully :)
# {'Job Title': 'Data Science Engineer - 100% Remote', 'Company Name': 'Radian', 'Location': 'Maryland', 'Salary Estimate': '$112,011 /yr (est.)', 'Rating': '4.2', 'Job Description': 'See yourself at Radian? We see you here too.\nAt Radian, we see you. For the person you are and the potential you hold. That’s why we’ve embraced a new way of working that lets our people across the country be themselves, be their best and be their boldest. Because when each of us is truly seen, each of us gives our best – and at Radian, we’ll give you our best right back.\nSee Yourself as a Data Science Engineer\nThe data science engineer works on a team which develops massively scalable, low latency, real-time streaming event-driven data-mesh infrastructure and batch process event-driven data lake architecture to support both internal operations and data science research, as well as highly available consumer-facing systems and APIs. The position works on developing a centralized analytics data infrastructure to ingest event-based data in real-time from both internal Radian systems and services as well as public data sources. This role is a key enabler for data science operations and will facilitate the creation of machine learning feature stores and data cleansing, normalizing, flattening and enrichment processes. These processes will aggregate thousands of columns of data to provide both customer 360 and property 360 data for state-of-the-art scientific AI model research and development, customer facing systems, as well as internal reporting. The data engineer will work in various data environments and systems including Kafka streaming, Spark batch processes, and various types of data stores including RDBMs, KVS, in-memory data stores, vector databases, and graph databases.'}
# {'size': '1001 to 5000 Employees', 'founded': '1977', 'type': 'Company - Public', 'industry': 'Insurance Carriers', 'sector': 'Insurance', 'revenue': '$1 to $2 billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  14/30
# job info error, trying again...
# {'Job Title': 'Data Science Analyst', 'Company Name': 'WIVERSE', 'Location': 'Remote', 'Salary Estimate': '$112,011 /yr (est.)', 'Rating': '4.1', 'Job Description': 'NO C2C/ Only W-2 Candidates.\nPurpose: The Data Science Analyst will support the leasing, development and marketing teams with insights gained from analyzing company data. The candidate must be adept at using large data sets to find opportunities and process optimization and using models to test the effectiveness of different courses of action. To succeed in this position, you must have strong experience using a variety of data mining/data analysis methods, using a variety of data tools, building, and implementing models, using/creating algorithms, and creating/running simulations. You must have a proven ability to drive business results with your data-based insights.\nJob Functions:\n1. Work with stakeholders throughout the organization to identify opportunities for leveraging company data to drive business solutions\n2. Mine and analyze data from company databases to drive optimization and improvement of product development, marketing techniques and business strategies\n3. Assess the effectiveness and accuracy of new data sources and data gathering techniques\n4. Develop custom data models and algorithms to apply to data sets\n5. Use predictive modeling to increase and optimize customer experiences, revenue generation, ad targeting and other business outcomes\n6. Coordinate with different functional teams to implement models and monitor outcomes\n7. Develop processes and tools to monitor and analyze model performance and data accuracy\n8. Develop company A/B testing framework and test model quality'}
# {'size': '51 to 200 Employees', 'founded': '2017', 'type': 'Company - Private', 'industry': 'Telecommunications Services', 'sector': 'Telecommunications', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  15/30
# job info collected successfully :)
# {'Job Title': 'Data science instructor', 'Company Name': 'MIM', 'Location': 'Remote', 'Salary Estimate': '$131,513 /yr (est.)', 'Rating': -1, 'Job Description': 'ABOUT MIM\nMIM is a New York based institution that offers management and technology courses since 1984. Given the growing demand for skilled and passionate data scientists, MIM is looking for experienced and passionate instructors for its Data Science Bootcamp. This program will allow our graduates to enhance their data analytics and technology skills hands-on by working with data, writing code and building machine learning models. It will help them find many new career opportunities for make career changes.\nhttps://www.mimusa.edu/\nJob Description\nRole Description'}
# size not found
# founded not found
# type not found
# industry not found
# sector not found
# revenue not found
# {'size': -1, 'founded': -1, 'type': -1, 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  16/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist', 'Company Name': 'Kani Solutions', 'Location': 'Remote', 'Salary Estimate': '$77.50 /hr (est.)', 'Rating': '4.6', 'Job Description': 'Position: Data Scientist\nLocation : Charlotte, NC\nJob Type : Full Time\nThis Data Scientist role will work with the Automation Delivery team, IT business partners, Functional consultants, and infrastructure/technology teams to meet customer requirements. You will focus primarily on the end-to-end delivery of ML/AI use cases from pilot/design to release, driving the evolution of ML/AI infrastructure/process, and enabling Cognitive Automation, AI ChatBot, etc.\nKey Responsibilities:\nDevelop and Deploy advanced Machine Learning, Reinforcement learning and Deep Learning Models/algorithms to enhance existing business processes with predictive and intelligent decision making.'}
# {'size': '201 to 500 Employees', 'founded': '2009', 'type': 'Company - Private', 'industry': 'Information Technology Support Services', 'sector': 'Information Technology', 'revenue': '$5 to $10 million (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  17/30
# job info error, trying again...
# {'Job Title': 'Assoc Data Analyst', 'Company Name': 'Disney Streaming', 'Location': 'San Francisco, CA', 'Salary Estimate': '$77.50 /hr (est.)', 'Rating': '3.1', 'Job Description': "The Disney Streaming Data and Analytics organization is seeking an Associate Data Analyst who will be an exceptional addition to our Advanced Analytics, Content team. As Associate Data Analyst, you will join our content team that applies analytical rigor to optimize our content portfolio, merchandising and release strategy.\n\nThe right person for this role has exceptional analytical capabilities, thrives in a fast-paced environment, loves problem-solving, is a strong communicator, and is passionate about television and movie content. If you are someone who gains personal satisfaction from utilizing data to drive business decisions and you're eager to learn, then this is a great role for you.\n\nResponsibilities :\nWHAT YOU’LL DO\n\n\nDISNEYTECH"}
# {'size': '501 to 1000 Employees', 'founded': '2018', 'type': 'Company - Private', 'industry': 'Internet & Web Services', 'sector': 'Information Technology', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  18/30
# job info collected successfully :)
# {'Job Title': 'Database Analyst I', 'Company Name': 'Stefanini, Inc', 'Location': 'Deerfield, IL', 'Salary Estimate': '$67,500 /yr (est.)', 'Rating': '3.7', 'Job Description': 'Stefanini Group is hiring for a Database Analyst I.\n\nExciting opportunity awaits! Let us help you get started. Call Aditya Yadav - (248-728-6487/ Aditya.Yadav@stefanini.com\n\nJob Title: Data Analyst\nTravel Requirements: Up to 40%\nTravel Locations:\nSkaneateles Falls, NY\nBatesville, IN\nZealand, MI\nDeerfield, IL\n\nSummary:'}
# {'size': '10000+ Employees', 'founded': '1987', 'type': 'Subsidiary or Business Segment', 'industry': 'Information Technology Support Services', 'sector': 'Information Technology', 'revenue': '$1 to $2 billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  19/30
# job info collected successfully :)
# {'Job Title': 'Data Analyst', 'Company Name': 'Hulu', 'Location': 'Santa Monica, CA', 'Salary Estimate': '$75,307 /yr (est.)', 'Rating': '3.9', 'Job Description': 'We are seeking a Data Analyst who will focus on analyzing subscriber retention and engagement. Collaborating across marketing, product, data engineering, data science and business teams, this position will design and implement reporting that enables internal clients to access, explore and monitor data, as well as perform analysis and share underlying trends and insights to help teams have a better understanding of the ESPN+ and Disney+ subscribers, audience behavior and engagement drivers.\nResponsibilities\nMine data, perform quantitative analysis and create clear and actionable narratives about our audience, their behaviors, and drivers of retention and engagement.\nPartner with colleagues facilitating the design, build and automation of reports / dashboards that provide insight into customer conversion and behavior.\nBuild intuitive interfaces, infographics, and visualizations to tell stories with data.'}
# {'size': '1001 to 5000 Employees', 'founded': '2007', 'type': 'Company - Private', 'industry': 'Broadcast Media', 'sector': 'Media & Communication', 'revenue': '$1 to $2 billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  20/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist', 'Company Name': 'Bayer', 'Location': 'Chesterfield, MO', 'Salary Estimate': '$115,000 /yr (est.)', 'Rating': '4.1', 'Job Description': 'At Bayer we’re visionaries, driven to solve the world’s toughest challenges and striving for a world where ,Health for all, Hunger for none’ is no longer a dream, but a real possibility. We’re doing it with energy, curiosity and sheer dedication, always learning from unique perspectives of those around us, expanding our thinking, growing our capabilities and redefining ‘impossible’. There are so many reasons to join us. If you’re hungry to build a varied and meaningful career in a community of brilliant and diverse minds to make a real difference, there’s only one choice.\n\nData Scientist\n\nYOUR TASKS AND RESPONSIBILITIES'}
# {'size': '10000+ Employees', 'founded': '1863', 'type': 'Company - Public', 'industry': 'Biotech & Pharmaceuticals', 'sector': 'Pharmaceutical & Biotechnology', 'revenue': '$10+ billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  21/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist', 'Company Name': 'nLeague services Inc.', 'Location': 'Remote', 'Salary Estimate': '$92.50 /hr (est.)', 'Rating': '3.8', 'Job Description': "Data Scientist\nLocation: 100% remote\nDuration: 12+ Months\nClient: OPB\nJob Id: 688616\nJob Description:\nState Agency: Governor's Office of Planning and Budget (OPB)\nJob Summary:"}
# {'size': '1 to 50 Employees', 'founded': '2001', 'type': 'Company - Private', 'industry': 'Information Technology Support Services', 'sector': 'Information Technology', 'revenue': 'Less than $1 million (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  22/30
# job info collected successfully :)
# {'Job Title': 'Faculty - Data Science', 'Company Name': 'Vanguard University', 'Location': 'Costa Mesa, CA', 'Salary Estimate': '$87,986 /yr (est.)', 'Rating': '4.0', 'Job Description': 'Department of Physical Sciences and Applied Mathematics\nPosition Description:\nThe Department of Physical Sciences and Applied Mathematics seeks applications for a full-time, term Data Science faculty position to begin in the Fall Semester, 2022. This position is renewable. Vanguard seeks professionals of Christian faith who are committed to integration of faith and learning in their respective fields. The ideal candidate will be enthusiastic about teaching a broad range of undergraduate courses in data science (and related areas of mathematics), will supply evidence of teaching excellence, and will have the ability to engage in development of the data science curriculum. Other responsibilities include academic advising, service to the department, and service to the college in support of its mission to educate, inspire, and empower its students in the context of a liberal arts curriculum. Opportunities include course development and participation in the undergraduate research program. In addition to a demonstrated teaching ability, applicants must have a commitment to working with and encouraging diversity. Courses to be taught would include:'}
# revenue not found
# {'size': '51 to 200 Employees', 'founded': 'College / University', 'type': 'Colleges & Universities', 'industry': 'Education', 'sector': '$50 to $100 million (USD)', 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  23/30
# job info error, trying again...
# {'Job Title': 'Executive Assistant, Data Science (Remote)', 'Company Name': 'CrowdStrike', 'Location': 'California', 'Salary Estimate': '$87,986 /yr (est.)', 'Rating': '4.4', 'Job Description': '#WeAreCrowdStrike and our mission is to stop breaches. As a global leader in cybersecurity, our team changed the game. Since our inception, our market leading cloud-native platform has offered unparalleled protection against the most sophisticated cyberattacks. We’re looking for people with limitless passion, a relentless focus on innovation and a fanatical commitment to the customer to join us in shaping the future of cybersecurity. Consistently recognized as a top workplace, CrowdStrike is committed to cultivating an inclusive, remote-first culture that offers people the autonomy and flexibility to balance the needs of work and life while taking their career to the next level. Interested in working for a company that sets the standard and leads with integrity? Join us on a mission that matters - one team, one fight.\nAbout the Role:\nWe are seeking a talented and highly motivated Executive Assistant that will be aligned to our CTO organization and capable of providing strategic and operational support to corporate executives at the VP level and above.\nKnowledge & Skills:'}
# {'size': '1001 to 5000 Employees', 'founded': '2011', 'type': 'Company - Public', 'industry': 'Enterprise Software & Network Solutions', 'sector': 'Information Technology', 'revenue': '$500 million to $1 billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  24/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist', 'Company Name': 'General Atomics and Affiliated Companies', 'Location': 'Poway, CA', 'Salary Estimate': '$94,110 /yr (est.)', 'Rating': '3.5', 'Job Description': 'General Atomics Aeronautical Systems, Inc. (GA-ASI), an affiliate of General Atomics, is a world leader in proven, reliable remotely piloted aircraft and tactical reconnaissance radars, as well as advanced high-resolution surveillance systems.\n\nUnder general direction, the position reports to a team in the Electrical Test Engineering organization, the Data Scientist is a dynamic position covering technology, people, process, and data strategies for the Test Automation Team. This role will coordinate and/or participate in the development of reports, processes, statistical models, analyses, etc. to meet department requirements in the group test and project data improvement. The candidate ensures data-related mapping, policies, procedures, and processes to address complex business needs.\n\nDUTIES AND RESPONSIBILITIES:\nCreate reports for internal teams and/or external clients.\n\nWe recognize and appreciate the value and contributions of individuals with diverse backgrounds and experiences and welcome all qualified individuals to apply.'}
# {'size': '10000+ Employees', 'founded': '1955', 'type': 'Company - Private', 'industry': 'Aerospace & Defense', 'sector': 'Aerospace & Defense', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  25/30
# job info collected successfully :)
# {'Job Title': 'Product Data Analyst', 'Company Name': 'busybusy, Inc.', 'Location': 'Remote', 'Salary Estimate': '$100,000 /yr (est.)', 'Rating': -1, 'Job Description': 'About busybusy\nbusybusy is a modern software service that helps construction companies operate more efficiently. We leverage our highly engaging timetracking service to solve a wide variety of problems for our customers including job-site documentation, scheduling, progress tracking, safety sign-off’s, and equipment tracking. busybusy’s main office is located in Saint George Utah and our team also includes many working out of Salt Lake, Denver, and other remote locations.\nOur mission is to improve the culture of construction by adding trust and transparency to enable companies to empower their people to eliminate waste, increase productivity and live happier work lives. And this starts with busybusy, that’s why we’re committed to building our own fantastic work culture built on integrity and collaboration.\nWe are looking for an experienced team member to join our remote Product team. As a member of the product team you will have considerable impact on the future of busybusy’s products, integrations, and feature decisions. The product team works directly with engineering, sales, marketing, senior leadership, external partners, and of course, our customers.'}
# size not found
# founded not found
# type not found
# industry not found
# sector not found
# revenue not found
# {'size': -1, 'founded': -1, 'type': -1, 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  26/30
# job info collected successfully :)
# {'Job Title': 'Data Analyst (Remote)', 'Company Name': 'pulseData', 'Location': 'New York, NY', 'Salary Estimate': '$70,000 /yr (est.)', 'Rating': '5.0', 'Job Description': "Join us as we pursue our vision to eliminate preventable sickness. We are a distributed team filled with people who are passionate about our product and seek to deliver the best experience for our customers. At pulseData, we’re committed to our work, our customers, having fun, and each other’s success.\n\npulseData leverages data science and machine learning for Hospitals and Healthcare companies, to identify patients at risk of costly and avoidable medical outcomes. Our bespoke suite of products not only impacts our customers, but it prevents the suffering of thousands of patients who can receive the care they need before they know they need it. The work you'll do here has a massive impact.\nThe Role:\nYou'll be making our data more accessible, understandable, and usable and assisting with client deliverables.\nYou'll be cleaning and scrubbing medical record data and claims data to ensure it can be used in our data pipelines."}
# {'size': '1 to 50 Employees', 'founded': '2015', 'type': 'Company - Private', 'industry': 'Health Care Services & Hospitals', 'sector': 'Healthcare', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  27/30
# job info collected successfully :)
# {'Job Title': 'Online Course Instructor - Analytics & Data Science (Part-Time, Contract)', 'Company Name': 'DataCamp', 'Location': 'Washington, DC', 'Salary Estimate': '$71,035 /yr (est.)', 'Rating': '3.7', 'Job Description': 'About Us:\nDataCamp is on a mission to make the world data fluent by building the future of scalable data education, assessments, certification and collaboration tools for data professionals. Since our launch more than 10 million learners around the world have completed hundreds of millions of DataCamp content items, and over 2,500 businesses and government entities worldwide use DataCamp to make their teams and organizations data fluent.\n\nWe will be massively scaling those numbers in 2022 and beyond, and want you to be a part of it!\nAbout the role:\nHigh quality course content and top-tier instruction are critical to our success. As an instructor, you will work with our content team to build a best-in-class data course that helps learners grasp new concepts and practice them through a hands-on learning experience! To be successful, you will need to take ownership over course development and production, collaborate with our curriculum experts and content team, and dedicate approximately per week over 12-16 weeks. No prior teaching experience is necessary. Our curriculum experts and content developers will help you every step of the way as you create the course!'}
# {'size': '51 to 200 Employees', 'founded': '2013', 'type': 'Company - Private', 'industry': 'Education & Training Services', 'sector': 'Education', 'revenue': '$50 to $100 million (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  28/30
# job info collected successfully :)
# {'Job Title': 'Jr. Data Analyst', 'Company Name': 'PepsiCo', 'Location': 'Plano, TX', 'Salary Estimate': '$58,085 /yr (est.)', 'Rating': '3.9', 'Job Description': "Auto req ID: 282581BR\n\nPepsiCo operates in an environment undergoing immense and rapid change. Big-data and digital technologies are driving business transformation that is unlocking new capabilities and business innovations in areas like eCommerce, mobile experiences and IoT. The key to winning in these areas is being able to leverage enterprise data foundations built on PepsiCo’s global business scale to enable business insights, advanced analytics and new product development. PepsiCo’s Data Management and Operations team is tasked with the responsibility of developing quality data collection processes, maintaining the integrity of our data foundations and enabling business leaders and data scientists across the company to have rapid access to the data they need for decision-making and innovation.\nWhat PepsiCo Data Management and Operations does:\nMaintain a predictable, transparent, global operating rhythm that ensures always-on access to high-quality data for stakeholders across the company\n\n\n\nAs a Data Analyst, you will be the key domain expert overseeing PepsiCo's business process and drive a strong discussion for how Supply Chain, Financial, Consumer, Channel, Category business needs to be defined and prioritize by working very closely with business leads, data science team and data engineering team. You'll develop an in-depth understanding of business processes in and translate business requirements to data engineering team in technical way.\nAccountabilities\n\n\n\nNot Eligible for Relocation\nRegular\n\nAll qualified applicants will receive consideration for employment without regard to race, color, religion, sex, sexual orientation, gender identity, national origin, protected veteran status, or disability status.\n\nPepsiCo is an Equal Opportunity Employer: Female / Minority / Disability / Protected Veteran / Sexual Orientation / Gender Identity\n\nOur Company will consider for employment qualified applicants with criminal histories in a manner consistent with the requirements of the Fair Credit Reporting Act, and all other applicable laws, including but not limited to, San Francisco Police Code Sections 4901 - 4919, commonly referred to as the San Francisco Fair Chance Ordinance; and Chapter XVII, Article 9 of the Los Angeles Municipal Code, commonly referred to as the Fair Chance Initiative for Hiring Ordinance.\n\nIf you'd like more information about your EEO rights as an applicant under the law, please download the available EEO is the Law & EEO is the Law Supplement documents. View PepsiCo EEO Policy\n\nPlease view our Pay Transparency Statement"}
# {'size': '10000+ Employees', 'founded': '1965', 'type': 'Company - Public', 'industry': 'Food & Beverage Manufacturing', 'sector': 'Manufacturing', 'revenue': '$10+ billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  29/30
# job info collected successfully :)
# {'Job Title': 'Data Science/Machine Learning Engineer', 'Company Name': 'mroads', 'Location': 'Plano, TX', 'Salary Estimate': '$104,443 /yr (est.)', 'Rating': '3.9', 'Job Description': 'Mroads is looking to hire “Data Science” with one of fortune 500 direct clients in Plano, TX. Ideal candidate should have strong Python, SQL and Tableau/Power BI experience.\nDescription:\nThis position will provide customer and marketing insight to the stakeholders through analysis, research, and modeling.\nProvide analytical support to the organization by leveraging data mining tools and analytical methodologies\nAssist in data modeling and analysis to determine key customer insights, drive business strategies, and maximize ROI\nIntegrate internal and external data sources, be comfortable working with both structured and unstructured data'}
# {'size': '201 to 500 Employees', 'founded': '2011', 'type': 'Private Practice / Firm', 'industry': 'Enterprise Software & Network Solutions', 'sector': 'Information Technology', 'revenue': '$10 to $25 million (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#                                             Job Title  \
# 0                               Junior Data Scientist
# 1                                    Mgr Data Science
# 2                                 Junior Data Analyst
# 3                                   Gcp data engineer
# 4                    Data Scientist - Personalization
# 5                                    Jr. Data Analyst
# 6                                      Data Scientist
# 7                              Data Science Assistant
# 8                                      Data Annotator
# 9                  Data Science and Signal Engineer I
# 10                                     Data Scientist
# 11        Data Science- Database/Applications Analyst
# 12  Data Science Engineer - (Day-1 Onsite w/ Flexi...
# 13                Data Science Engineer - 100% Remote
# 14                               Data Science Analyst
# 15                            Data science instructor
# 16                                     Data Scientist
# 17                                 Assoc Data Analyst
# 18                                 Database Analyst I
# 19                                       Data Analyst
# 20                                     Data Scientist
# 21                                     Data Scientist
# 22                             Faculty - Data Science
# 23         Executive Assistant, Data Science (Remote)
# 24                                     Data Scientist
# 25                               Product Data Analyst
# 26                              Data Analyst (Remote)
# 27  Online Course Instructor - Analytics & Data Sc...
# 28                                   Jr. Data Analyst
# 29             Data Science/Machine Learning Engineer
#
#                                 Company Name           Location  \
# 0                             Talentheed Inc             Remote
# 1                                 South West         Dallas, TX
# 2                        Human Exponent Inc.             Remote
# 3                             Infinity Quest             Remote
# 4                                    Audible         Newark, NJ
# 5                                    PepsiCo        Chicago, IL
# 6                            IV IT Solutions             Remote
# 7                             United Nations       New York, NY
# 8                                    Skit.ai       New York, NY
# 9                                  Medtronic     Northridge, CA
# 10                              Infologitech             Remote
# 11                    Salud Revenue Partners             Remote
# 12                       Serve Professionals    San Antonio, TX
# 13                                    Radian           Maryland
# 14                                   WIVERSE             Remote
# 15                                       MIM             Remote
# 16                            Kani Solutions             Remote
# 17                          Disney Streaming  San Francisco, CA
# 18                            Stefanini, Inc      Deerfield, IL
# 19                                      Hulu   Santa Monica, CA
# 20                                     Bayer   Chesterfield, MO
# 21                     nLeague services Inc.             Remote
# 22                       Vanguard University     Costa Mesa, CA
# 23                               CrowdStrike         California
# 24  General Atomics and Affiliated Companies          Poway, CA
# 25                            busybusy, Inc.             Remote
# 26                                 pulseData       New York, NY
# 27                                  DataCamp     Washington, DC
# 28                                   PepsiCo          Plano, TX
# 29                                    mroads          Plano, TX
#
#         Salary Estimate Rating  \
# 0   $100,000 /yr (est.)     -1
# 1   $103,267 /yr (est.)    4.2
# 2   $103,267 /yr (est.)    5.0
# 3    $100.00 /hr (est.)    4.3
# 4    $85,503 /yr (est.)    4.0
# 5    $57,332 /yr (est.)    3.9
# 6     $82.50 /hr (est.)    5.0
# 7    $88,585 /yr (est.)    4.0
# 8    $46,817 /yr (est.)    4.5
# 9    $46,817 /yr (est.)    4.1
# 10    $85.00 /hr (est.)    4.3
# 11   $52,000 /yr (est.)    4.5
# 12  $110,000 /yr (est.)    2.4
# 13  $112,011 /yr (est.)    4.2
# 14  $112,011 /yr (est.)    4.1
# 15  $131,513 /yr (est.)     -1
# 16    $77.50 /hr (est.)    4.6
# 17    $77.50 /hr (est.)    3.1
# 18   $67,500 /yr (est.)    3.7
# 19   $75,307 /yr (est.)    3.9
# 20  $115,000 /yr (est.)    4.1
# 21    $92.50 /hr (est.)    3.8
# 22   $87,986 /yr (est.)    4.0
# 23   $87,986 /yr (est.)    4.4
# 24   $94,110 /yr (est.)    3.5
# 25  $100,000 /yr (est.)     -1
# 26   $70,000 /yr (est.)    5.0
# 27   $71,035 /yr (est.)    3.7
# 28   $58,085 /yr (est.)    3.9
# 29  $104,443 /yr (est.)    3.9
#
#                                       Job Description                    size  \
# 0   Responsibilities:\nWork with stakeholders to d...                      -1
# 1   Department: Business Transformation\n\nOur Com...        10000+ Employees
# 2   We are seeking a highly motivated analyst to j...       1 to 50 Employees
# 3   Hello ,\nGood day,\nInfinity Quest is seeking ...    201 to 500 Employees
# 4   Job summary\nGood storytelling starts with gre...  1001 to 5000 Employees
# 5   This position can be located in Plano, Texas -...        10000+ Employees
# 6   Hello,\nHope you are doing great!\nThis is jam...       1 to 50 Employees
# 7   This position is located in the Analytics Sect...        10000+ Employees
# 8   About us\nSkit (previously known as Vernacular...     51 to 200 Employees
# 9   Careers that Change Lives\nEngineers create ou...        10000+ Employees
# 10  Qualifications:\n-10+ years experience with R,...       1 to 50 Employees
# 11  Salud Revenue Partners (Salud) is a technology...     51 to 200 Employees
# 12  Data Science Engineer - (Day-1 Onsite w/ Flexi...                 Unknown
# 13  See yourself at Radian? We see you here too.\n...  1001 to 5000 Employees
# 14  NO C2C/ Only W-2 Candidates.\nPurpose: The Dat...     51 to 200 Employees
# 15  ABOUT MIM\nMIM is a New York based institution...                      -1
# 16  Position: Data Scientist\nLocation : Charlotte...    201 to 500 Employees
# 17  The Disney Streaming Data and Analytics organi...   501 to 1000 Employees
# 18  Stefanini Group is hiring for a Database Analy...        10000+ Employees
# 19  We are seeking a Data Analyst who will focus o...  1001 to 5000 Employees
# 20  At Bayer we’re visionaries, driven to solve th...        10000+ Employees
# 21  Data Scientist\nLocation: 100% remote\nDuratio...       1 to 50 Employees
# 22  Department of Physical Sciences and Applied Ma...     51 to 200 Employees
# 23  #WeAreCrowdStrike and our mission is to stop b...  1001 to 5000 Employees
# 24  General Atomics Aeronautical Systems, Inc. (GA...        10000+ Employees
# 25  About busybusy\nbusybusy is a modern software ...                      -1
# 26  Join us as we pursue our vision to eliminate p...       1 to 50 Employees
# 27  About Us:\nDataCamp is on a mission to make th...     51 to 200 Employees
# 28  Auto req ID: 282581BR\n\nPepsiCo operates in a...        10000+ Employees
# 29  Mroads is looking to hire “Data Science” with ...    201 to 500 Employees
#
#                  founded                                     type  \
# 0                     -1                                       -1
# 1                   1967                         Company - Public
# 2      Company - Private                 Unknown / Non-Applicable
# 3                   2006                        Company - Private
# 4                   1995           Subsidiary or Business Segment
# 5                   1965                         Company - Public
# 6      Company - Private                 Unknown / Non-Applicable
# 7                   1945                               Government
# 8                   2016                        Company - Private
# 9                   1949                         Company - Public
# 10     Company - Private  Information Technology Support Services
# 11                  2011                        Company - Private
# 12      Company - Public                 Unknown / Non-Applicable
# 13                  1977                         Company - Public
# 14                  2017                        Company - Private
# 15                    -1                                       -1
# 16                  2009                        Company - Private
# 17                  2018                        Company - Private
# 18                  1987           Subsidiary or Business Segment
# 19                  2007                        Company - Private
# 20                  1863                         Company - Public
# 21                  2001                        Company - Private
# 22  College / University                  Colleges & Universities
# 23                  2011                         Company - Public
# 24                  1955                        Company - Private
# 25                    -1                                       -1
# 26                  2015                        Company - Private
# 27                  2013                        Company - Private
# 28                  1965                         Company - Public
# 29                  2011                  Private Practice / Firm
#
#                                    industry  \
# 0                                        -1
# 1   Airlines, Airports & Air Transportation
# 2                                        -1
# 3   Information Technology Support Services
# 4                           Film Production
# 5             Food & Beverage Manufacturing
# 6                                        -1
# 7                         National Agencies
# 8   Enterprise Software & Network Solutions
# 9        Health Care Products Manufacturing
# 10                   Information Technology
# 11                            HR Consulting
# 12                                       -1
# 13                       Insurance Carriers
# 14              Telecommunications Services
# 15                                       -1
# 16  Information Technology Support Services
# 17                  Internet & Web Services
# 18  Information Technology Support Services
# 19                          Broadcast Media
# 20                Biotech & Pharmaceuticals
# 21  Information Technology Support Services
# 22                                Education
# 23  Enterprise Software & Network Solutions
# 24                      Aerospace & Defense
# 25                                       -1
# 26         Health Care Services & Hospitals
# 27            Education & Training Services
# 28            Food & Beverage Manufacturing
# 29  Enterprise Software & Network Solutions
#
#                                 sector                           revenue
# 0                                   -1                                -1
# 1           Transportation & Logistics                $10+ billion (USD)
# 2                                   -1                                -1
# 3               Information Technology          Unknown / Non-Applicable
# 4                Media & Communication          Unknown / Non-Applicable
# 5                        Manufacturing                $10+ billion (USD)
# 6                                   -1                                -1
# 7   Government & Public Administration          Unknown / Non-Applicable
# 8               Information Technology            $1 to $5 million (USD)
# 9                        Manufacturing                $10+ billion (USD)
# 10              $1 to $5 million (USD)                                -1
# 11          Human Resources & Staffing          Unknown / Non-Applicable
# 12                                  -1                                -1
# 13                           Insurance            $1 to $2 billion (USD)
# 14                  Telecommunications          Unknown / Non-Applicable
# 15                                  -1                                -1
# 16              Information Technology           $5 to $10 million (USD)
# 17              Information Technology          Unknown / Non-Applicable
# 18              Information Technology            $1 to $2 billion (USD)
# 19               Media & Communication            $1 to $2 billion (USD)
# 20      Pharmaceutical & Biotechnology                $10+ billion (USD)
# 21              Information Technology        Less than $1 million (USD)
# 22           $50 to $100 million (USD)                                -1
# 23              Information Technology  $500 million to $1 billion (USD)
# 24                 Aerospace & Defense          Unknown / Non-Applicable
# 25                                  -1                                -1
# 26                          Healthcare          Unknown / Non-Applicable
# 27                           Education         $50 to $100 million (USD)
# 28                       Manufacturing                $10+ billion (USD)
# 29              Information Technology          $10 to $25 million (USD)

# %%
response_to_dataframe(df,"Glassdoor_jobs1")
# Out:
#                                     Job Title  \
# 0                          Jr. Data Scientist
# 1               Data Scientist - Intermediate
# 2                                Data Analyst
# 3                              Data Scientist
# 4                               Data Engineer
# 5                              Data Scientist
# 6                     Data Science Consultant
# 7                               Data Engineer
# 8                       Data Science Engineer
# 9                              Data Scientist
# 10                    Data Mentor (Part-time)
# 11                    Data Science Consultant
# 12                      Junior Data Scientist
# 13                    Data Scientist (Junior)
# 14  Data Engineer II ( Patient Data) - AI/ ML
# 15    Data Scientist, Data Science & Modeling
# 16         Data Scientist or Bioinformatician
# 17                          Data Science Lead
# 18                Data Scientist (Healthtech)
# 19                             Data Scientist
# 20            Student Employee - Data Science
# 21                         Assoc Data Analyst
# 22                     Data Science Assistant
# 23                             Data Scientist
# 24                      Junior Data Scientist
# 25                             Data Scientist
# 26                             Data Scientist
# 27                             Data Scientist
# 28                               Data Science
# 29                      Sports data scientist
#
#                            Company Name               Location  \
# 0                            Net2Aspire                 Remote
# 1                              Envision                 Remote
# 2                                  Hulu       Santa Monica, CA
# 3                     Mint-Technologies           Richmond, VA
# 4                              Vedainfo                 Remote
# 5                     SIL International                 Remote
# 6                             Accenture          San Diego, CA
# 7                           WALTLabs.io                 Remote
# 8                    Moorecroft Systems                 Remote
# 9                               Geocomp                 Remote
# 10                             Pathrise                 Remote
# 11                          Emonics LLC             Austin, TX
# 12                                Acima             Draper, UT
# 13                                 BDSA         Louisville, CO
# 14                    Change Healthcare                 Remote
# 15                            CardWorks       South Jordan, UT
# 16       UT Southwestern Medical Center                 Remote
# 17                          Trissential        Minneapolis, MN
# 18  Alldus International Consulting Ltd                 Remote
# 19                                 GGWP                 Remote
# 20    Electric Power Research Institute          Charlotte, NC
# 21                     Disney Streaming      San Francisco, CA
# 22                       United Nations           New York, NY
# 23                FriendFinder Networks                 Remote
# 24                       Talentheed Inc                 Remote
# 25                                 SHGT             Denver, CO
# 26                           ClosedLoop             Austin, TX
# 27                      Flipside Crypto                 Remote
# 28                            NSABrands  Greenwood Village, CO
# 29                           MOORvision                 Remote
#
#         Salary Estimate Rating  \
# 0    $72,500 /yr (est.)     -1
# 1    $72,500 /yr (est.)    1.0
# 2    $75,266 /yr (est.)    3.9
# 3     $75.00 /hr (est.)     -1
# 4     $55.00 /hr (est.)    4.1
# 5    $70,000 /yr (est.)    4.3
# 6   $105,150 /yr (est.)    4.1
# 7   $110,000 /yr (est.)     -1
# 8     $52.50 /hr (est.)     -1
# 9     $55.00 /hr (est.)    3.9
# 10    $45.00 /hr (est.)    4.6
# 11  $125,000 /yr (est.)    4.6
# 12   $80,000 /yr (est.)    3.7
# 13  $100,000 /yr (est.)    1.4
# 14  $132,500 /yr (est.)    3.4
# 15  $134,452 /yr (est.)    3.1
# 16   $93,500 /yr (est.)    3.9
# 17  $107,497 /yr (est.)    3.9
# 18  $140,000 /yr (est.)     -1
# 19  $137,500 /yr (est.)     -1
# 20   $83,020 /yr (est.)    5.0
# 21   $87,945 /yr (est.)    3.2
# 22   $88,606 /yr (est.)    4.0
# 23  $110,000 /yr (est.)    3.0
# 24  $100,000 /yr (est.)     -1
# 25  $140,000 /yr (est.)    1.0
# 26   $91,911 /yr (est.)    4.8
# 27   $91,911 /yr (est.)    5.0
# 28   $97,500 /yr (est.)    5.0
# 29   $97,500 /yr (est.)     -1
#
#                                       Job Description                    size  \
# 0    Apply Statistical and Machine Learning metho...                      -1
# 1   Basic Qualifications:\n1. Master's Degree in S...                 Unknown
# 2   We are seeking a Data Analyst who will focus o...  1001 to 5000 Employees
# 3   *will work ONSITE 2-3 days each week\nThe data...       1 to 50 Employees
# 4   Data Engineer\nLocation: This position is remo...    201 to 500 Employees
# 5   Job Description Summary:\nThe data scientist w...     51 to 200 Employees
# 6   We are:\nApplied Intelligence, the people who ...        10000+ Employees
# 7   WALTLabs.io is looking for an experienced and ...                      -1
# 8   Senior Data Science Engineer\nMoorecroft is lo...     51 to 200 Employees
# 9   Geocomp (a Sercel company) is looking for an e...     51 to 200 Employees
# 10  What is Pathrise?\nPathrise (YC W18) connects ...     51 to 200 Employees
# 11  JOB TITLE: DATA SCIENCE\nLOCATION: AUSTIN,TX\n...   501 to 1000 Employees
# 12  ACIMA\nAcima Credit is a young and dynamic lea...   501 to 1000 Employees
# 13  Job Summary: The Analytics team empowers BDSA ...                 Unknown
# 14  Data Engineer II - AI/ Machine Learning\nFTE- ...        10000+ Employees
# 15  Merrick Bank employees share in our mission to...   501 to 1000 Employees
# 16  Center Information:\nThe Quantitative Biomedic...        10000+ Employees
# 17  Overview\nTrissential’s a trusted partner for ...    201 to 500 Employees
# 18  Job Title: Data Scientist (Healthcare)\nLocati...                      -1
# 19  GGWP is a fast-paced start-up co-founded by fo...                      -1
# 20  Job Title:\nStudent Employee - Data Science\nL...                 Unknown
# 21  The Disney Streaming Data and Analytics organi...   501 to 1000 Employees
# 22  This position is located in the Analytics Sect...        10000+ Employees
# 23  WHAT WE WANT\nFriendFinder Networks is looking...    201 to 500 Employees
# 24  Responsibilities:\nWork with stakeholders to d...                      -1
# 25  Must have Skills : Python, AWS\nJob Descriptio...                 Unknown
# 26  About ClosedLoop:\nClosedLoop.ai is healthcare...     51 to 200 Employees
# 27  Flipside Crypto is seeking a Data Scientist to...       1 to 50 Employees
# 28  Company:\nNational Storage Affiliates Trust is...   501 to 1000 Employees
# 29  Breakout entertainment/analytical technology i...                      -1
#
#                    founded                                     type  \
# 0                       -1                                       -1
# 1        Company - Private                 Unknown / Non-Applicable
# 2                     2007                        Company - Private
# 3        Company - Private                 Unknown / Non-Applicable
# 4        Company - Private  Information Technology Support Services
# 5   Nonprofit Organization                  Culture & Entertainment
# 6                     1989                         Company - Public
# 7                       -1                                       -1
# 8         Company - Public                 Unknown / Non-Applicable
# 9                     1983                        Company - Private
# 10                    2017                        Company - Private
# 11                    2018                        Company - Private
# 12                    2013                         Company - Public
# 13       Company - Private           Advertising & Public Relations
# 14                    2007                         Company - Public
# 15                    1987                        Company - Private
# 16                    1943                                 Hospital
# 17                    2003           Subsidiary or Business Segment
# 18                      -1                                       -1
# 19                      -1                                       -1
# 20       Company - Private                 Unknown / Non-Applicable
# 21                    2018                        Company - Private
# 22                    1945                               Government
# 23                    1996                        Company - Private
# 24                      -1                                       -1
# 25        Company - Public                 Unknown / Non-Applicable
# 26                    2017                        Company - Private
# 27       Company - Private                 Unknown / Non-Applicable
# 28                    2013                         Company - Public
# 29                      -1                                       -1
#
#                                    industry  \
# 0                                        -1
# 1                                        -1
# 2                           Broadcast Media
# 3                                        -1
# 4                    Information Technology
# 5          Arts, Entertainment & Recreation
# 6                       Business Consulting
# 7                                        -1
# 8                                        -1
# 9      Architectural & Engineering Services
# 10            Education & Training Services
# 11                            HR Consulting
# 12                        Banking & Lending
# 13                    Media & Communication
# 14  Information Technology Support Services
# 15                        Banking & Lending
# 16         Health Care Services & Hospitals
# 17                      Business Consulting
# 18                                       -1
# 19                                       -1
# 20                                       -1
# 21                  Internet & Web Services
# 22                        National Agencies
# 23                  Internet & Web Services
# 24                                       -1
# 25                                       -1
# 26  Enterprise Software & Network Solutions
# 27                                       -1
# 28                      Property Management
# 29                                       -1
#
#                                          sector                     revenue
# 0                                            -1                          -1
# 1                                            -1                          -1
# 2                         Media & Communication      $1 to $2 billion (USD)
# 3                                            -1                          -1
# 4                        $1 to $5 million (USD)                          -1
# 5                      Unknown / Non-Applicable                          -1
# 6                       Management & Consulting          $10+ billion (USD)
# 7                                            -1                          -1
# 8                                            -1                          -1
# 9   Construction, Repair & Maintenance Services    $10 to $25 million (USD)
# 10                                    Education      $1 to $5 million (USD)
# 11                   Human Resources & Staffing   $50 to $100 million (USD)
# 12                           Financial Services    Unknown / Non-Applicable
# 13                     Unknown / Non-Applicable                          -1
# 14                       Information Technology    Unknown / Non-Applicable
# 15                           Financial Services   $50 to $100 million (USD)
# 16                                   Healthcare      $2 to $5 billion (USD)
# 17                      Management & Consulting    $25 to $50 million (USD)
# 18                                           -1                          -1
# 19                                           -1                          -1
# 20                                           -1                          -1
# 21                       Information Technology    Unknown / Non-Applicable
# 22           Government & Public Administration    Unknown / Non-Applicable
# 23                       Information Technology    $25 to $50 million (USD)
# 24                                           -1                          -1
# 25                                           -1                          -1
# 26                       Information Technology    Unknown / Non-Applicable
# 27                                           -1                          -1
# 28                   Personal Consumer Services  $100 to $500 million (USD)
# 29                                           -1                          -1

# %%
df.to_csv('jobs.csv')
