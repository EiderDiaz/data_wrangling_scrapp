# %%
from selenium import webdriver
import sys
import time
#sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import pandas as pd

# %% [markdown]
# ### setup
# antes de correr debes descargar el chrome driver acorde a tu maquina
# https://sites.google.com/chromium.org/driver/downloads

# %% [markdown]
# ### helper functions

# %%
def init_scrapper(keyword="data science", headless = False ):
    """"initialize the glassdor scrapper given a job keyword"""
    # Initializing the webdriver
    options = webdriver.ChromeOptions()

    #Uncomment the line below if you'd like to scrape without a new Chrome window every time.
    if headless: options.add_argument('headless')

    #Change the path to where chromedriver is in your home folder.
    #driver = webdriver.Chrome(executable_path=driverpath, options=options)

    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    url = "https://www.glassdoor.com/Job/jobs.htm?suggestCount=0&suggestChosen=false&clickSource=searchBtn&typedKeyword="+keyword+"&sc.keyword="+keyword+"&locT=&locId=&jobType="
    driver.get(url)

    return driver


def get_companyname_rating(company_name):
    """gets the company name and (if exist) gets the company rating too"""
    splited = company_name.split("\n")
    #company name comes with rating 
    if len(splited) > 1:
        return splited[0],  splited[1]
    #just company name
    else:
        return company_name, -1


def get_company_overview_data(Company_Overview):
    """"gets the company overview data (dont the name of the func speaks for itself?)"""
    Company_Overview_dict = {"size":"",
                            "founded":"",
                            "type":"",
                            "industry":"",
                            "sector":"",
                            "revenue":"",}

    for i, key in enumerate(Company_Overview_dict):
        try: 
            Company_Overview_dict[key] = Company_Overview[i].text
        except:
            print(f"{key} not found")
            Company_Overview_dict[key] = -1
    return Company_Overview_dict


def response_to_dataframe(list_of_dicts,filename):
  """cast list of dict into df, if filename is specified exports the csv """
  df = pd.DataFrame(list_of_dicts)
  if filename:
    df.to_csv(f'./{filename}.csv')
  return df

# %%
#path = ""
keyword = "data science"
init_scrapper(keyword)

# %% [markdown]
# ### SCRAPPER

# %%
def get_jobs(keyword, num_jobs, verbose, slp_time, failsafe = False):
    
    """Gathers jobs as a dataframe, scraped from Glassdoor"""
    driver = init_scrapper(keyword)
    jobs = []
    #Let the page load. Change this number based on your internet speed.
    time.sleep(2*slp_time)
    while len(jobs) < num_jobs:  #If true, should be still looking for new jobs.

        #Going through each job in this page
        job_buttons = driver.find_elements(By.CLASS_NAME, "react-job-listing")  #react-job-listing for Job Listing. These are the buttons we're going to click.
        print(f"size job buttons {len(job_buttons)}")
        for job_button in job_buttons:  

            print(f"Progress:  {len(jobs)}/{ num_jobs}")
            if len(jobs) >= num_jobs:
                break
            job_button.click()  #You might 
            time.sleep(slp_time)
            # Test for the "Sign Up" prompt and get rid of it.
            # close modal (just appear on the first pass)
            if len(jobs) == 0:
                try:
                    driver.find_element(By.XPATH, '//*[@id="JAModal"]/div/div[2]/span').click()
                    #driver.find_element(By.CLASS_NAME,'modal_closeIcon').click()
                    print("modal cerrado con exito")
                except NoSuchElementException:
                    print("no hay modal xd")
                    
            collected_successfully = False
            while not collected_successfully:
                try:

                    company_name_ = driver.find_element(By.CLASS_NAME, 'e1tk4kwz5').text
                    #sometimes company name comes with the rating, if its the case get_companyname_rating handles it
                    company_name, rating = get_companyname_rating(company_name_) 
                    location = driver.find_element(By.CLASS_NAME,'e1tk4kwz1').text
                    job_title = driver.find_element(By.CLASS_NAME,'e1tk4kwz2').text
                    job_description = driver.find_element(By.XPATH,'.//div[@class="jobDescriptionContent desc"]').text
                    salary_estimate = driver.find_element(By.CLASS_NAME,'e2u4hf18').text if driver.find_element(By.CLASS_NAME,'e2u4hf18') else "N/A"
                    collected_successfully = True
                    print("job info collected successfully :)")
                except:
                    time.sleep(slp_time/2)
                    print("job info error, trying again...")
                    break

            job_data_dict = {"Job Title" : job_title,
                            "Company Name" : company_name,
                            "Location" : location,
                            "Salary Estimate" : salary_estimate,
                            "Rating" : rating,
                            "Job Description" : job_description,
                        }

            #Printing for debugging
            if verbose:
                print(job_data_dict)

            #Going to the Company tab...
            #clicking on this:
            #<div class="tab" data-tab-type="overview"><span>Company</span></div>
            try:
                Company_Overview = driver.find_elements(By.CLASS_NAME,'e1pvx6aw0')
                company_overview_dict = get_company_overview_data(Company_Overview)

            except NoSuchElementException:  #Rarely, some job postings do not have the "Company" tab.
                company_overview_dict = {"size":-1,
                                        "founded":-1,
                                        "type":-1,
                                        "industry":-1,
                                        "sector":-1,
                                        "revenue":-1}
                
            if verbose:
                print(company_overview_dict)
                print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
            
            job_data_dict.update(company_overview_dict)

            jobs.append(job_data_dict)
            if failsafe: response_to_dataframe(jobs,"jobs_df")

            #add job to jobs
            
            
        #Clicking on the "next page" button
        try:
            driver.find_element(By.CLASS_NAME,'nextButton').click()
            time.sleep(slp_time/2)
        except NoSuchElementException:
            print("Scraping terminated before reaching target number of jobs. Needed {}, got {}.".format(num_jobs, len(jobs)))
            break
        
    driver.close()
    return pd.DataFrame(jobs)  #This line converts the dictionary object into a pandas DataFrame.

# %%
# https://stackoverflow.com/questions/60362018/macos-catalinav-10-15-3-error-chromedriver-cannot-be-opened-because-the-de
#path = "/opt/homebrew/bin/chromedriver"
keyword = "data science"
num_jobs = 30
slp_time = 6
verbose = True
failsafe = True

df = get_jobs(keyword, num_jobs, verbose, slp_time,failsafe)
df
# Out:
# size job buttons 30
# Progress:  0/30
# modal cerrado con exito
# job info collected successfully :)
# {'Job Title': 'Junior Data Scientist', 'Company Name': 'Talentheed Inc', 'Location': 'Remote', 'Salary Estimate': '$100,000 /yr (est.)', 'Rating': -1, 'Job Description': 'Responsibilities:\nWork with stakeholders to determine how to use business data for valuable business solutions.\nSearch for ways to get new data sources and assess their accuracy.\nBrowse and analyze enterprise databases to simplify and improve product development, marketing techniques, and business processes.\nCreate custom data models and algorithms.\nUse predictive models to improve customer experience, ad targeting, revenue generation, and more.\nDevelop the organization’s test model quality and A/B testing framework.'}
# size not found
# founded not found
# type not found
# industry not found
# sector not found
# revenue not found
# {'size': -1, 'founded': -1, 'type': -1, 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  1/30
# job info collected successfully :)
# {'Job Title': 'Student Employee - Data Science', 'Company Name': 'Electric Power Research Institute', 'Location': 'Charlotte, NC', 'Salary Estimate': '$83,007 /yr (est.)', 'Rating': '5.0', 'Job Description': 'Job Title:\nStudent Employee - Data Science\nLocation:\nCharlotte, NC\nJob Summary and Description:\nThis role is primarily related to Data Science, so degree programs focused on scientific disciplines in this area are preferred.\nCandidates will support subject matter experts and data scientists in a variety of data analysis tasks that may include: literature review; data review and preparation; model development and implementation; and model results review and assessment.\nThis opportunity will require the candidate to be in a degree program that is focused on engineering or scientific disciplines. These include, but are not limited to:'}
# industry not found
# sector not found
# revenue not found
# {'size': 'Unknown', 'founded': 'Company - Private', 'type': 'Unknown / Non-Applicable', 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  2/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist, Data Science & Modeling', 'Company Name': 'CardWorks', 'Location': 'South Jordan, UT', 'Salary Estimate': '$134,452 /yr (est.)', 'Rating': '3.1', 'Job Description': 'Merrick Bank employees share in our mission to delight our customers and empower underserved consumers to achieve their credit goals. In return, we delight our associates; ensuring they are noticed, heard, appreciated and understand the importance of their role(s). For over 20 years, our Guiding Principles of; doing the right thing, putting the customer first, and Earn, Learn, Have Fun (aka E.L.F.), have defined who we are as an Employer of Choice. Give Yourself Credit, Work at Merrick!\nThe Data Scientist position will work closely with the other Data Scientists and Data Engineers on the team to produce the machine learning models, statistical models, and complex statistical analyses for the bank. This position works on state of the art problems, using state of the art systems, on a team with dozens of years of combined expertise and experience that truly believes in team work, as well as individual growth and development.'}
# {'size': '501 to 1000 Employees', 'founded': '1987', 'type': 'Company - Private', 'industry': 'Banking & Lending', 'sector': 'Financial Services', 'revenue': '$50 to $100 million (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  3/30
# job info collected successfully :)
# {'Job Title': 'Data Science Engineer', 'Company Name': 'Moorecroft Systems', 'Location': 'Remote', 'Salary Estimate': '$52.50 /hr (est.)', 'Rating': -1, 'Job Description': 'Senior Data Science Engineer\nMoorecroft is looking to hire a seasoned Data Science Engineer with experience working with petabyte-size data sets to assist one of our Global Media Company clients. They are leaders in the entertainment and streaming business. This consulting role will continue for multiple years and can done Remotely.\nThe role will be to work closely with their Data Science and CRM teams to leverage a multitude of Data assets sources to reach impactful and actionable data driven insights. You will lead cross function Sprints, champion best coding practices of Data Science teams, build relationships with business partners.\nCore Skills and Experience needed'}
# industry not found
# sector not found
# revenue not found
# {'size': '51 to 200 Employees', 'founded': 'Company - Public', 'type': 'Unknown / Non-Applicable', 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  4/30
# job info collected successfully :)
# {'Job Title': 'Data Science Engineer', 'Company Name': 'Dataquestcorp', 'Location': 'Branchburg, NJ', 'Salary Estimate': '$75,000 /yr (est.)', 'Rating': -1, 'Job Description': 'We are providing free training and placement opportunity on data science like python, tableau, Machine learning and Bigdata.\nBenefits:\nFree Training and placement.\nH1B Sponsorship\nWe do support for STEM OPT and GC processing.\nHealth Insurance\nRelocation Assistance any where in USA.'}
# size not found
# founded not found
# type not found
# industry not found
# sector not found
# revenue not found
# {'size': -1, 'founded': -1, 'type': -1, 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  5/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist III', 'Company Name': 'GTA (Global Technology Associates)', 'Location': 'Englewood, CO', 'Salary Estimate': '$80,000 /yr (est.)', 'Rating': '4.4', 'Job Description': 'Looking for a Data Scientist III\nWhat you will be doing as a Data Scientist III\nCreate applications using video analytics algorithms across different verticals\nCreate demos and PoCs using open-source libraries (GitHub) and hardware like Raspberry PI, Nvidia Jetson.\nCollect and feature engineer data to train AI/ML models\nExecute test cases and report results.\nDebug equipment issues and collect logs.\nWrite scripts to automate testing and collect data.'}
# industry not found
# sector not found
# revenue not found
# {'size': 'Unknown', 'founded': 'Company - Private', 'type': 'Unknown / Non-Applicable', 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  6/30
# job info error, trying again...
# {'Job Title': 'BHJOB15656_16794 - Data Scientist', 'Company Name': 'Myticas Consulting', 'Location': 'Remote', 'Salary Estimate': '$80,000 /yr (est.)', 'Rating': '3.7', 'Job Description': "The recruitment team here at Myticas is looking to hire 2 Data Scientists to assist with building our client's nextgen (next generation) of advanced analytics products using AI, Data Science, and ML (Machine learning).\nThe Data Scientists we are seeking will collaborate across internal teams to create predictive models and identify opportunities to make informed business decisions and create value for our customer base. The primary responsibilities will be applying a knowledge of statistics, machine learning (ML) programming, data modeling, simulation, and advanced mathematics for recognizing patterns, identify opportunities, posing business questions, and making valuable discoveries leading to prototype development and new product offerings.\nREQUIREMENTS:"}
# revenue not found
# {'size': '1 to 50 Employees', 'founded': 'Company - Private', 'type': 'Information Technology Support Services', 'industry': 'Information Technology', 'sector': 'Unknown / Non-Applicable', 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  7/30
# job info collected successfully :)
# {'Job Title': 'Data science instructor', 'Company Name': 'MIM', 'Location': 'Remote', 'Salary Estimate': '$131,513 /yr (est.)', 'Rating': -1, 'Job Description': 'ABOUT MIM\nMIM is a New York based institution that offers management and technology courses since 1984. Given the growing demand for skilled and passionate data scientists, MIM is looking for experienced and passionate instructors for its Data Science Bootcamp. This program will allow our graduates to enhance their data analytics and technology skills hands-on by working with data, writing code and building machine learning models. It will help them find many new career opportunities for make career changes.\nhttps://www.mimusa.edu/\nJob Description'}
# size not found
# founded not found
# type not found
# industry not found
# sector not found
# revenue not found
# {'size': -1, 'founded': -1, 'type': -1, 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  8/30
# job info collected successfully :)
# {'Job Title': 'Junior Data Scientist', 'Company Name': 'Augray', 'Location': 'Brookfield, WI', 'Salary Estimate': '$57,500 /yr (est.)', 'Rating': '4.3', 'Job Description': 'Brookfield, WI, USA\nSummary:\nHiring Fresher to 1 year experience in Data Science, ML with python and strong analytical skills with a passion to take part in R&D.\nAbout AugRay:\nAugray is on a mission to build next generation method of communication using Extended Reality – XR (AR/ VR/ MR) technologies and change the way businesses re conducted and how interactions happen with people. In an age where innovation is happening all around us, there’s commonality – people are driving these changes. We offer a solution that helps to articulate product demonstration and how people conversation takes place using smartphones and wearable glasses.'}
# {'size': '51 to 200 Employees', 'founded': '2014', 'type': 'Subsidiary or Business Segment', 'industry': 'Information Technology Support Services', 'sector': 'Information Technology', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  9/30
# job info collected successfully :)
# {'Job Title': 'Data Science Assistant', 'Company Name': 'United Nations', 'Location': 'New York, NY', 'Salary Estimate': '$88,585 /yr (est.)', 'Rating': '4.0', 'Job Description': 'This position is located in the Analytics Section of the Analytics and Project Management Service of the Business Transformation and Accountability Division (BTAD) in the Department of Management Strategy, Policy and Compliance (DMSPC). The incumbent reports to a Data Scientist.\n\nFor more information, please visit https://www.un.org/management/content/our-offices.\nResponsibilities\nWithin delegated authority, the Data Science Assistant will be responsible for the following duties:\n\nAssists with the preparation of input for response to requests for exploration, identification, and acquisition of data sources to determine their suitability for use in decision making and advancing the goals of the organization.\nCompetencies\n\n\n\nEducation\nWork Experience\n\n\n\n\n\n\n\n\nLanguages\nAssessment\nSpecial Notice\n\n\n\n\n\n\nUnited Nations Considerations\n\n\n\n\n\n\n\n\n\n\nNo Fee'}
# {'size': '10000+ Employees', 'founded': '1945', 'type': 'Government', 'industry': 'National Agencies', 'sector': 'Government & Public Administration', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  10/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist (Junior)', 'Company Name': 'BDSA', 'Location': 'Louisville, CO', 'Salary Estimate': '$100,000 /yr (est.)', 'Rating': '1.4', 'Job Description': 'Job Summary: The Analytics team empowers BDSA through the development of syndicated market research products based on various datasets. As a Junior Data Scientist, you will work on highly complex projects supporting the Product and Professional Services teams with data wrangling, data cleaning, and data reporting tools and techniques.\nYour day-to-day activities will involve using heterogeneous datasets to derive insights and automation. For example, combining public weather data with proprietary sales data to identify trends and build forecasts, or using ML/AI tools to parse large datasets and deduplicate data.\nQC/QA processes are critical elements of this work and you will spend substantial time automating and managing automated QC/QA systems. The datasets grow substantially day by day and automation of the QC/QA environment is a top priority.'}
# revenue not found
# {'size': 'Unknown', 'founded': 'Company - Private', 'type': 'Advertising & Public Relations', 'industry': 'Media & Communication', 'sector': 'Unknown / Non-Applicable', 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  11/30
# job info collected successfully :)
# {'Job Title': 'Data Engineer', 'Company Name': 'Amazon', 'Location': 'Remote', 'Salary Estimate': '$275,000 /yr (est.)', 'Rating': '3.8', 'Job Description': "BASIC QUALIFICATIONS\n5+ years of experience as a Data Engineer or in a similar role\nBachelor's degree in Computer Science, Engineering, Mathematics, or a related technical discipline.\n4+ years of industry experience in Software Development, Data Engineering, Business Intelligence, Data Science, or related field with a track record of manipulating, processing, and extracting value from large datasets.\nPREFERRED QUALIFICATIONS\nMasters in computer science, mathematics, statistics, economics, or other quantitative fields."}
# {'size': '10000+ Employees', 'founded': '1994', 'type': 'Company - Public', 'industry': 'Internet & Web Services', 'sector': 'Information Technology', 'revenue': '$10+ billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  12/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist', 'Company Name': 'Infologitech', 'Location': 'Remote', 'Salary Estimate': '$85.00 /hr (est.)', 'Rating': '4.3', 'Job Description': "Qualifications:\n-10+ years experience with R, SQL, Python, or other data science programming languages; OR Master's/PhD degree and 5+ years experience\nSkills\nData science, artificial intelligence and machine learning projects Required 3 Years\nData Analysis Tools - Python, R, RStudio, Jupyter Notebooks, SQL, Tableau Required 3 Years\nBuilding and Training Machine Learning Models Required 3 Years\nDatabase management Nice to have 3 Years"}
# revenue not found
# {'size': '1 to 50 Employees', 'founded': 'Company - Private', 'type': 'Information Technology Support Services', 'industry': 'Information Technology', 'sector': '$1 to $5 million (USD)', 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  13/30
# job info collected successfully :)
# {'Job Title': 'Junior Data Scientist', 'Company Name': 'Acima', 'Location': 'Draper, UT', 'Salary Estimate': '$80,000 /yr (est.)', 'Rating': '3.7', 'Job Description': 'ACIMA\nAcima Credit is a young and dynamic leasing company that provides consumers financing options for life necessities that otherwise would not be available to them. We help with financing options from tires/wheels to furniture and appliances. Acima blends the use of innovative online technology with a fast and easy application process for thousands of retailers nationwide. Customers love us because we make the impossible possible. Retailers love us because we make it easy for them.\nSummary:\nWe are looking for a developing data scientist that is interested in applying their understanding of machine learning techniques and statistics to analyze our many complex datasets. They will be nose deep in interesting payment, behavioral, credit, fraud, and economic datasets, to name a few. The insights gleaned and models trained from the analyses done on these datasets can quickly change the course of the company.'}
# {'size': '501 to 1000 Employees', 'founded': '2013', 'type': 'Company - Public', 'industry': 'Banking & Lending', 'sector': 'Financial Services', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  14/30
# job info collected successfully :)
# {'Job Title': 'Data Science Analytics Deveoper', 'Company Name': 'Capgemini', 'Location': 'New York, NY', 'Salary Estimate': '$113,281 /yr (est.)', 'Rating': '3.8', 'Job Description': 'Data Science Analytics Developer\nFT Base+Bonus+Benefits- New York Based\nJob Responsibilities\nData Science Analytics Developer Lead Skills required Experienced professional with 10 12 years of experience developing and implementing statistical models in Big Data ecosystem i e Hadoop Spark HBase Hive Impala or any other similar distributed computing technology Proficiency with Python R and basic libraries for statistical econometric modeling such as scikit learn pandas\nExperienced in Hadoop Spark HDFS Python R PySpark and other leading technologies Proficiency with DataIku or similar tools Proficiency in data analysis using complex and optimized SQL and or above mentioned technologies Understanding of data architecture structures data modeling and database design and performance management'}
# {'size': '10000+ Employees', 'founded': '1967', 'type': 'Company - Public', 'industry': 'Enterprise Software & Network Solutions', 'sector': 'Information Technology', 'revenue': '$10+ billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  15/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist', 'Company Name': 'Openmind Technologies', 'Location': 'Vacaville, CA', 'Salary Estimate': '$57.50 /hr (est.)', 'Rating': -1, 'Job Description': 'Duration: 6 months\nJob Responsibilities include (but are not limited to):\nResponsible for executing data engineering/analysis tasks, and writing reports to support data analysis solutions or model validation\nResponsible for coordinating technical meetings and supporting process experts to translate a problem from the process/equipment domain into data engineering or analysis domain\nIdentifies opportunities for data science to overcome technology challenges\nSkills\nSome knowledge of statistical process control and data analysis techniques\nHave experience working with equipment in the laboratory, pilot plant, or manufacturing settings\nGeneral knowledge of the underlying scientific principles applied to the development and manufacture of biopharmaceuticals.\nSome understanding of the following software: R and/or Python\nUnderstanding machine learning or experience in first principal modeling is a plus'}
# size not found
# founded not found
# type not found
# industry not found
# sector not found
# revenue not found
# {'size': -1, 'founded': -1, 'type': -1, 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  16/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist', 'Company Name': '3G Federal Solutions, LLC', 'Location': 'Remote', 'Salary Estimate': '$115,000 /yr (est.)', 'Rating': -1, 'Job Description': 'Tasks (illustrative) – Forecasts and models to inform system capacity planning, including controlling for demographic- or health-related limiting factors; analysis of key performance indicators; throughput analyses; policy impact evaluations\nRequired Skills (Mathematicians) – Bayesian statistics, Probability theory, linear algebra, combinatorics, graph theory, numerical analysis, moving averages\nRequired Skills (Data Scientists) – Predictive analytics, ARIMA forecasting, timeseries analyses, linear/non-linear optimization, simulation techniques (e.g., Arena, Monte Carlo); anomaly detection, text distance, geospatial analyses, database modeling (relational and non-relational)\nJob Type: Full-time'}
# industry not found
# sector not found
# revenue not found
# {'size': 'Unknown', 'founded': 'Company - Public', 'type': 'Unknown / Non-Applicable', 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  17/30
# job info collected successfully :)
# {'Job Title': 'Data Mentor (Part-time)', 'Company Name': 'Pathrise', 'Location': 'Remote', 'Salary Estimate': '$45.00 /hr (est.)', 'Rating': '4.6', 'Job Description': 'What is Pathrise?\nPathrise (YC W18) connects job seekers across North America to world class industry mentorship and career coaching to help them land a new career. The program is free upfront and our customers pay us back when they’re hired.\n\nBuilt around aligned incentives, we help build equity in the job search process by providing 1-on-1 mentorship, training, and a platform to uplift job seekers and ultimately, help them fulfill their hopes, ambitions, and livelihoods. We’ve already helped more than a thousand fellows land meaningful jobs, and helped them earn over $100M in salary.\n\nLast year, we raised our Series A and there is even more exciting growth on the horizon. In 2022, we have already expanded from 6 to 14 industries, launched a tiered pricing system with differentiated product offerings, and much more.'}
# {'size': '51 to 200 Employees', 'founded': '2017', 'type': 'Company - Private', 'industry': 'Education & Training Services', 'sector': 'Education', 'revenue': '$1 to $5 million (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  18/30
# job info collected successfully :)
# {'Job Title': 'Data Science Associate (Remote)', 'Company Name': 'pulseData', 'Location': 'New York, NY', 'Salary Estimate': '$59,834 /yr (est.)', 'Rating': '5.0', 'Job Description': "pulseData is changing the way healthcare data is utilized within major healthcare sectors. As a series A health-tech startup, we provide the insights necessary for medical staff to understand who has and is at risk of major chronic illnesses. We have rooted ourselves within the Kidney space, and have the capabilities of bringing our approach to many more patient populations given our capabilities.\n\nWe recently raised $16.5M in our series A and are growing fast. This means we are onboarding brilliant people and providing endless areas for our employees to grow their careers. We believe in trust and transparency, and enjoy a remote friendly working environment that promotes collaboration and diversity.\nThe Role:\nIn your role as a Data Science Associate, you will use machine learning to deliver insightful and actionable intelligence and predictive solutions to our team to improve Healthcare growth in our business. You will gain experience understanding healthcare and developing data driven solutions to improve care delivery, while working closely with other team members of our Data Science and engineering team to deliver value to our business partners. Aside from supporting our data science model creation and data teams, you'll also assist the product team with growth opportunities."}
# {'size': '1 to 50 Employees', 'founded': '2015', 'type': 'Company - Private', 'industry': 'Health Care Services & Hospitals', 'sector': 'Healthcare', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  19/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist - Personalization', 'Company Name': 'Audible', 'Location': 'Newark, NJ', 'Salary Estimate': '$85,503 /yr (est.)', 'Rating': '4.0', 'Job Description': "Job summary\nGood storytelling starts with great listening. At Audible, that means each role and every project has our audience in mind. Because the same people who design, develop, and deploy our products also happen to use them. To us, that speaks volumes.\n\nABOUT THE ROLE\nHey – there’s a revolution going on! A revolution in digital entertainment. Every day millions of people around the world choose to be more thoughtfully entertained, informed and educated by listening to fascinating stories and all forms of fictional and non-fictional content. Want to shape the future of this innovation through statistics and machine learning? If so, this may be a great fit for you!\n\nAs Data Scientist - Personalization, you will make the best of your skillset in predictive modeling to explain, quantify, predict and prescribe in support of informing critical business decisions. You will translate business goals into agile, insightful analytics. You will seek to create value for both stakeholders and customers, and will inform findings in a clear, actionable way to managers and senior leaders.\n\nABOUT THE TEAM\nThe Audible Data Science Team partners with marketing, content, product, and technology partners to solve business and technology problems using scientific approaches to build product and services that surprise and delight our customers. We employ scalable cutting-edge machine learning (ML), deep learning (DL), and Natural Language Processing (NLP) knowledge to better target customers and prospects, understand and personalize the content, and context needed to optimize their book-listening experience. We operate in an agile environment in which we own and collaborate on the life cycle of research, design, and model development of relevant projects.\n\nWe are looking for motivated, results-oriented Data Scientist with strong rigor and demonstrable skills in Machine Learning, Deep Learning, Natural Language Processing, data mining and/or large-scale distributed computation.\n\nAs a Data Scientist - Personalization, you will...\n\nBasic Qualifications\n\nPreferred Qualifications\n\nABOUT AUDIBLE\nAt Audible, we innovate and inspire through the power of voice. We're changing the narrative on storytelling. As a leading creator and provider of premium audio storytelling, we've redefined the ways people access, discover, and share stories. The stories we tell have the ability to transport and transform everyday moments into meaningful experiences and it's our people who make Audible's service possible. We're listeners, storytellers, and problem-solvers. Our perspectives and experiences power our ideas and come together in our mission to unleash the power of the spoken word. Audible offers a Hub+Home hybrid workplace model that gives employees flexibility between gathering in a common office space (work from hub) and remote work (work from home). Some teams will work mostly at hub, some mostly at home and others hybrid. For more information, please visit adbl.co/hybrid.\n\nAudible is committed to a diverse and inclusive workplace. Audible is an equal opportunity employer and does not discriminate on the basis of race, national origin, gender, gender identity, sexual orientation, protected veteran status, disability, age, or other legally protected status. For individuals with disabilities who would like to request an accommodation, please visit https://www.amazon.jobs/en/disability/us."}
# {'size': '1001 to 5000 Employees', 'founded': '1995', 'type': 'Subsidiary or Business Segment', 'industry': 'Film Production', 'sector': 'Media & Communication', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  20/30
# job info collected successfully :)
# {'Job Title': 'Advanced Data Engineer', 'Company Name': 'Kroger', 'Location': 'Remote', 'Salary Estimate': '$135,196 /yr (est.)', 'Rating': '3.1', 'Job Description': "POSITION SUMMARY\nAccountable for leading activities that create deliverables to guide the direction, development, and delivery of technological responses to targeted business outcomes. Provide facilitation, analysis and design tasks required for the development of an enterprise's data and information architecture, focusing on data asset for the enterprise. Develop reusable standards, design patterns, guidelines, and configurations to evolve the technical infrastructure related to data and information across the enterprise, including direct collaboration with 84.51. Demonstrate the company’s core values of respect, honesty, integrity, diversity, inclusion and safety.\nESSENTIAL JOB FUNCTIONS:"}
# revenue not found
# {'size': '10000+ Employees', 'founded': 'Company - Public', 'type': 'Grocery Stores', 'industry': 'Retail & Wholesale', 'sector': '$10+ billion (USD)', 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  21/30
# job info collected successfully :)
# {'Job Title': 'Software Engineer - Data Science', 'Company Name': 'Datadog', 'Location': 'New York, NY', 'Salary Estimate': '$120,117 /yr (est.)', 'Rating': '4.2', 'Job Description': 'The Data Science team designs and builds algorithmically driven features in the Datadog app. We work across a range of applications, primarily focusing on analysis on streaming data such as anomaly detection, error outliers and faulty deployment analysis. As a Software Engineer on the Data Science team, you will design, build and scale the backend systems that power our growing suite of Watchdog products. You will be working on large-scale distributed systems, horizontally-scalable datastores and a variety of data-processing frameworks to build our next-generation platform and capabilities for Data Science at Datadog.\nAt Datadog, we place value in our office culture - the relationships that it builds, the creativity it brings to the table, and the collaboration of being together. We operate as a hybrid workplace to ensure our employees can create a work-life harmony that best fits them.'}
# {'size': '1001 to 5000 Employees', 'founded': '2010', 'type': 'Company - Public', 'industry': 'Enterprise Software & Network Solutions', 'sector': 'Information Technology', 'revenue': '$100 to $500 million (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  22/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist', 'Company Name': 'Motivated Leads', 'Location': 'Remote', 'Salary Estimate': '$240,000 /mo (est.)', 'Rating': -1, 'Job Description': 'Data Scientist with Digital Space Experience\nWe are looking for a Data Scientist to analyze large amounts of raw information to find patterns that will help improve our company. We will rely on you to build data products to extract valuable business insights.\nIn this role, you should be highly analytical with a knack for analysis, math and statistics. Critical thinking and problem-solving skills are essential for interpreting data. We also want to see a passion for machine-learning and research.\nYour goal will be to help our company analyze trends to make better decisions.\nCompensation:'}
# size not found
# founded not found
# type not found
# industry not found
# sector not found
# revenue not found
# {'size': -1, 'founded': -1, 'type': -1, 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  23/30
# job info collected successfully :)
# {'Job Title': 'Data Engineer', 'Company Name': 'WALTLabs.io', 'Location': 'Remote', 'Salary Estimate': '$110,000 /yr (est.)', 'Rating': -1, 'Job Description': 'WALTLabs.io is looking for an experienced and talented Data Engineer. The data engineer will be responsible for designing and building data pipelines within the GCP Ecosystem. This position will be partly client-facing.\nResponsibilities\nBuild data systems and pipelines\nEvaluate business needs and objectives\nPrepare data for prescriptive and predictive modeling\nCombine raw information from different sources\nDaily delivery of work inside JIRA'}
# size not found
# founded not found
# type not found
# industry not found
# sector not found
# revenue not found
# {'size': -1, 'founded': -1, 'type': -1, 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  24/30
# job info error, trying again...
# {'Job Title': 'Instructor, Data Science', 'Company Name': 'Bloom Institute of Technology', 'Location': 'Remote', 'Salary Estimate': '$110,000 /yr (est.)', 'Rating': '3.7', 'Job Description': 'We started Bloom Institute of Technology because we believe that the “traditional” model of higher education is broken. Every year, people as young as 17 years old take on tens of thousands of dollars in student debt and pray that the education they’re investing in will land them on a job on the other side.\n\u200d\nUnfortunately, traditional colleges and universities have no incentive to ensure their graduates get hired – they get paid regardless.\n\u200d\nAt BloomTech, we believe there is a better way to approach education.\n\nInstead of asking our students to bet on us, we bet on them first. This paradigm-shifting model allows us to align the incentives of the school with the incentives of our students – and we all win when our graduates succeed.\n\u200d'}
# {'size': '51 to 200 Employees', 'founded': '2017', 'type': 'Company - Private', 'industry': 'Education & Training Services', 'sector': 'Education', 'revenue': 'Unknown / Non-Applicable'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  25/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist', 'Company Name': 'Sia Partners', 'Location': 'New York, NY', 'Salary Estimate': '$117,500 /yr (est.)', 'Rating': '4.0', 'Job Description': 'Company Description\n\nSia Partners is a next-generation consulting firm focused on delivering superior value and tangible results to its clients as they navigate the digital revolution. Our global footprint and expertise in more than 40 sectors and services allow us to enhance our clients’ businesses worldwide. We guide their projects and initiatives in strategy, business transformation, IT & digital strategy, and Data Science.\nWHY JOIN THE SIA VILLAGE?\nExcellence | Entrepreneurship | Innovation | Teamwork | Care & Support | Employee Wellbeing\nThese are the six core values that guide all our actions. As an expression of our values, our Sia Village concept describes our commitment to fostering a sense of community within and among our offices. We believe that knowledge sharing is the key, not only to innovation, but to the growth and development of our people.'}
# {'size': '1001 to 5000 Employees', 'founded': '1999', 'type': 'Company - Private', 'industry': 'Business Consulting', 'sector': 'Management & Consulting', 'revenue': '$100 to $500 million (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  26/30
# job info collected successfully :)
# {'Job Title': 'Data Analyst', 'Company Name': 'Iver Solutions, LLC', 'Location': 'Seattle, WA', 'Salary Estimate': '$71.00 /hr (est.)', 'Rating': '2.3', 'Job Description': 'IBM/TikTok\nData Analyst\nLocation: Candidate needs to be in Los Angeles, Mountain View, CA or Seattle, WA location (NO REMOTE)\nDuration:\nStart Date: ASAP\nFor this Data Analyst position, looking for Sr resource who can lead the team and MUST have Digital Advertisement experience in social media company.'}
# industry not found
# sector not found
# revenue not found
# {'size': 'Unknown', 'founded': 'Company - Private', 'type': 'Unknown / Non-Applicable', 'industry': -1, 'sector': -1, 'revenue': -1}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  27/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist II - 100% Remote', 'Company Name': 'Radian', 'Location': 'Maryland', 'Salary Estimate': '$123,648 /yr (est.)', 'Rating': '4.2', 'Job Description': 'See yourself at Radian? We see you here too.\nAt Radian, we see you. For the person you are and the potential you hold. That’s why we’ve embraced a new way of working that lets our people across the country be themselves, be their best and be their boldest. Because when each of us is truly seen, each of us gives our best – and at Radian, we’ll give you our best right back.\nSee Yourself as a Data Scientist II\nThe Data Scientist II proactively uses predictive analytics and innovative machine learning models to create value from data. You will participate in designing, developing and evolving high quality, extensible modeling solutions and interpretation of results using a variety of techniques ranging from simple data aggregation to complex data mining, alogorithm development, and statistical analysis. You will design and develop inventive solutions to drive innovation and delivery of organizational value. You’ll synthesize large datasets and solve complex problems through the use of advanced machine learning and statistical modeling. You’ll work in a highly collaborative, team environment, collaborating with multiple stakeholders. You will assist management in the communication of insights and the implementation of impactful data science solutions across the organization.'}
# {'size': '1001 to 5000 Employees', 'founded': '1977', 'type': 'Company - Public', 'industry': 'Insurance Carriers', 'sector': 'Insurance', 'revenue': '$1 to $2 billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  28/30
# job info collected successfully :)
# {'Job Title': 'Data Scientist', 'Company Name': 'Dataworks', 'Location': 'Remote', 'Salary Estimate': '$122,500 /yr (est.)', 'Rating': -1, 'Job Description': 'Data Scientist\nUnited States - Remote\nCompetitive Salary plus Benefits and Bonus\nTECH STACK: Python / R, SQL, PowerBI / Tableau, AWS / GCP\nThis is an exciting opportunity to join one of the fastest growing tech companies in the US, they are looking for an experienced Data Scientist whose role will be to provide key insights to business problems and work on predictive and machine learning algorithms through to deployment.\nABOUT THE COMPANY'}
# {'size': '1 to 50 Employees', 'founded': '2021', 'type': 'Company - Private', 'industry': 'Information Technology Support Services', 'sector': 'Information Technology', 'revenue': '$1 to $5 million (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress:  29/30
# job info error, trying again...
# {'Job Title': 'Data Science and Signal Engineer I', 'Company Name': 'Medtronic', 'Location': 'Northridge, CA', 'Salary Estimate': '$122,500 /yr (est.)', 'Rating': '4.1', 'Job Description': 'Careers that Change Lives\nEngineers create our market-leading portfolio of innovations. Combine the best of your experience with training and mentorship to move forward. If you want a challenging, energizing, rewarding career that changes lives, join us. Help us bring the next generation of life-changing medical technology to patients worldwide.\n\nA Day in the Life\nWe are looking for an enthusiastic individual with strong analytical skills to join our algorithm development and data analytics team at Medtronic Diabetes (Northridge, CA). The position involves the support of research and development of medical devices related to continuous glucose monitors. The individual will work with members of research staff to improve the performance of continuous glucose sensors through the application of machine learning, analytics, signal processing and mathematical modeling and experimentation. The role will involve all aspects of the research process, including data processing, analysis, theory development and validation.'}
# {'size': '10000+ Employees', 'founded': '1949', 'type': 'Company - Public', 'industry': 'Health Care Products Manufacturing', 'sector': 'Manufacturing', 'revenue': '$10+ billion (USD)'}
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#                                   Job Title  \
# 0                     Junior Data Scientist
# 1           Student Employee - Data Science
# 2   Data Scientist, Data Science & Modeling
# 3                     Data Science Engineer
# 4                     Data Science Engineer
# 5                        Data Scientist III
# 6         BHJOB15656_16794 - Data Scientist
# 7                   Data science instructor
# 8                     Junior Data Scientist
# 9                    Data Science Assistant
# 10                  Data Scientist (Junior)
# 11                            Data Engineer
# 12                           Data Scientist
# 13                    Junior Data Scientist
# 14          Data Science Analytics Deveoper
# 15                           Data Scientist
# 16                           Data Scientist
# 17                  Data Mentor (Part-time)
# 18          Data Science Associate (Remote)
# 19         Data Scientist - Personalization
# 20                   Advanced Data Engineer
# 21         Software Engineer - Data Science
# 22                           Data Scientist
# 23                            Data Engineer
# 24                 Instructor, Data Science
# 25                           Data Scientist
# 26                             Data Analyst
# 27          Data Scientist II - 100% Remote
# 28                           Data Scientist
# 29       Data Science and Signal Engineer I
#
#                           Company Name          Location      Salary Estimate  \
# 0                       Talentheed Inc            Remote  $100,000 /yr (est.)
# 1    Electric Power Research Institute     Charlotte, NC   $83,007 /yr (est.)
# 2                            CardWorks  South Jordan, UT  $134,452 /yr (est.)
# 3                   Moorecroft Systems            Remote    $52.50 /hr (est.)
# 4                        Dataquestcorp    Branchburg, NJ   $75,000 /yr (est.)
# 5   GTA (Global Technology Associates)     Englewood, CO   $80,000 /yr (est.)
# 6                   Myticas Consulting            Remote   $80,000 /yr (est.)
# 7                                  MIM            Remote  $131,513 /yr (est.)
# 8                               Augray    Brookfield, WI   $57,500 /yr (est.)
# 9                       United Nations      New York, NY   $88,585 /yr (est.)
# 10                                BDSA    Louisville, CO  $100,000 /yr (est.)
# 11                              Amazon            Remote  $275,000 /yr (est.)
# 12                        Infologitech            Remote    $85.00 /hr (est.)
# 13                               Acima        Draper, UT   $80,000 /yr (est.)
# 14                           Capgemini      New York, NY  $113,281 /yr (est.)
# 15               Openmind Technologies     Vacaville, CA    $57.50 /hr (est.)
# 16           3G Federal Solutions, LLC            Remote  $115,000 /yr (est.)
# 17                            Pathrise            Remote    $45.00 /hr (est.)
# 18                           pulseData      New York, NY   $59,834 /yr (est.)
# 19                             Audible        Newark, NJ   $85,503 /yr (est.)
# 20                              Kroger            Remote  $135,196 /yr (est.)
# 21                             Datadog      New York, NY  $120,117 /yr (est.)
# 22                     Motivated Leads            Remote  $240,000 /mo (est.)
# 23                         WALTLabs.io            Remote  $110,000 /yr (est.)
# 24       Bloom Institute of Technology            Remote  $110,000 /yr (est.)
# 25                        Sia Partners      New York, NY  $117,500 /yr (est.)
# 26                 Iver Solutions, LLC       Seattle, WA    $71.00 /hr (est.)
# 27                              Radian          Maryland  $123,648 /yr (est.)
# 28                           Dataworks            Remote  $122,500 /yr (est.)
# 29                           Medtronic    Northridge, CA  $122,500 /yr (est.)
#
#    Rating                                    Job Description  \
# 0      -1  Responsibilities:\nWork with stakeholders to d...
# 1     5.0  Job Title:\nStudent Employee - Data Science\nL...
# 2     3.1  Merrick Bank employees share in our mission to...
# 3      -1  Senior Data Science Engineer\nMoorecroft is lo...
# 4      -1  We are providing free training and placement o...
# 5     4.4  Looking for a Data Scientist III\nWhat you wil...
# 6     3.7  The recruitment team here at Myticas is lookin...
# 7      -1  ABOUT MIM\nMIM is a New York based institution...
# 8     4.3  Brookfield, WI, USA\nSummary:\nHiring Fresher ...
# 9     4.0  This position is located in the Analytics Sect...
# 10    1.4  Job Summary: The Analytics team empowers BDSA ...
# 11    3.8  BASIC QUALIFICATIONS\n5+ years of experience a...
# 12    4.3  Qualifications:\n-10+ years experience with R,...
# 13    3.7  ACIMA\nAcima Credit is a young and dynamic lea...
# 14    3.8  Data Science Analytics Developer\nFT Base+Bonu...
# 15     -1  Duration: 6 months\nJob Responsibilities inclu...
# 16     -1  Tasks (illustrative) – Forecasts and models to...
# 17    4.6  What is Pathrise?\nPathrise (YC W18) connects ...
# 18    5.0  pulseData is changing the way healthcare data ...
# 19    4.0  Job summary\nGood storytelling starts with gre...
# 20    3.1  POSITION SUMMARY\nAccountable for leading acti...
# 21    4.2  The Data Science team designs and builds algor...
# 22     -1  Data Scientist with Digital Space Experience\n...
# 23     -1  WALTLabs.io is looking for an experienced and ...
# 24    3.7  We started Bloom Institute of Technology becau...
# 25    4.0  Company Description\n\nSia Partners is a next-...
# 26    2.3  IBM/TikTok\nData Analyst\nLocation: Candidate ...
# 27    4.2  See yourself at Radian? We see you here too.\n...
# 28     -1  Data Scientist\nUnited States - Remote\nCompet...
# 29    4.1  Careers that Change Lives\nEngineers create ou...
#
#                       size            founded  \
# 0                       -1                 -1
# 1                  Unknown  Company - Private
# 2    501 to 1000 Employees               1987
# 3      51 to 200 Employees   Company - Public
# 4                       -1                 -1
# 5                  Unknown  Company - Private
# 6        1 to 50 Employees  Company - Private
# 7                       -1                 -1
# 8      51 to 200 Employees               2014
# 9         10000+ Employees               1945
# 10                 Unknown  Company - Private
# 11        10000+ Employees               1994
# 12       1 to 50 Employees  Company - Private
# 13   501 to 1000 Employees               2013
# 14        10000+ Employees               1967
# 15                      -1                 -1
# 16                 Unknown   Company - Public
# 17     51 to 200 Employees               2017
# 18       1 to 50 Employees               2015
# 19  1001 to 5000 Employees               1995
# 20        10000+ Employees   Company - Public
# 21  1001 to 5000 Employees               2010
# 22                      -1                 -1
# 23                      -1                 -1
# 24     51 to 200 Employees               2017
# 25  1001 to 5000 Employees               1999
# 26                 Unknown  Company - Private
# 27  1001 to 5000 Employees               1977
# 28       1 to 50 Employees               2021
# 29        10000+ Employees               1949
#
#                                        type  \
# 0                                        -1
# 1                  Unknown / Non-Applicable
# 2                         Company - Private
# 3                  Unknown / Non-Applicable
# 4                                        -1
# 5                  Unknown / Non-Applicable
# 6   Information Technology Support Services
# 7                                        -1
# 8            Subsidiary or Business Segment
# 9                                Government
# 10           Advertising & Public Relations
# 11                         Company - Public
# 12  Information Technology Support Services
# 13                         Company - Public
# 14                         Company - Public
# 15                                       -1
# 16                 Unknown / Non-Applicable
# 17                        Company - Private
# 18                        Company - Private
# 19           Subsidiary or Business Segment
# 20                           Grocery Stores
# 21                         Company - Public
# 22                                       -1
# 23                                       -1
# 24                        Company - Private
# 25                        Company - Private
# 26                 Unknown / Non-Applicable
# 27                         Company - Public
# 28                        Company - Private
# 29                         Company - Public
#
#                                    industry  \
# 0                                        -1
# 1                                        -1
# 2                         Banking & Lending
# 3                                        -1
# 4                                        -1
# 5                                        -1
# 6                    Information Technology
# 7                                        -1
# 8   Information Technology Support Services
# 9                         National Agencies
# 10                    Media & Communication
# 11                  Internet & Web Services
# 12                   Information Technology
# 13                        Banking & Lending
# 14  Enterprise Software & Network Solutions
# 15                                       -1
# 16                                       -1
# 17            Education & Training Services
# 18         Health Care Services & Hospitals
# 19                          Film Production
# 20                       Retail & Wholesale
# 21  Enterprise Software & Network Solutions
# 22                                       -1
# 23                                       -1
# 24            Education & Training Services
# 25                      Business Consulting
# 26                                       -1
# 27                       Insurance Carriers
# 28  Information Technology Support Services
# 29       Health Care Products Manufacturing
#
#                                 sector                     revenue
# 0                                   -1                          -1
# 1                                   -1                          -1
# 2                   Financial Services   $50 to $100 million (USD)
# 3                                   -1                          -1
# 4                                   -1                          -1
# 5                                   -1                          -1
# 6             Unknown / Non-Applicable                          -1
# 7                                   -1                          -1
# 8               Information Technology    Unknown / Non-Applicable
# 9   Government & Public Administration    Unknown / Non-Applicable
# 10            Unknown / Non-Applicable                          -1
# 11              Information Technology          $10+ billion (USD)
# 12              $1 to $5 million (USD)                          -1
# 13                  Financial Services    Unknown / Non-Applicable
# 14              Information Technology          $10+ billion (USD)
# 15                                  -1                          -1
# 16                                  -1                          -1
# 17                           Education      $1 to $5 million (USD)
# 18                          Healthcare    Unknown / Non-Applicable
# 19               Media & Communication    Unknown / Non-Applicable
# 20                  $10+ billion (USD)                          -1
# 21              Information Technology  $100 to $500 million (USD)
# 22                                  -1                          -1
# 23                                  -1                          -1
# 24                           Education    Unknown / Non-Applicable
# 25             Management & Consulting  $100 to $500 million (USD)
# 26                                  -1                          -1
# 27                           Insurance      $1 to $2 billion (USD)
# 28              Information Technology      $1 to $5 million (USD)
# 29                       Manufacturing          $10+ billion (USD)

# %%
trabajos_df =  response_to_dataframe(df,"Glassdoor_jobs1")
trabajos_df
# Out:
#                                   Job Title  \
# 0                     Junior Data Scientist
# 1           Student Employee - Data Science
# 2   Data Scientist, Data Science & Modeling
# 3                     Data Science Engineer
# 4                     Data Science Engineer
# 5                        Data Scientist III
# 6         BHJOB15656_16794 - Data Scientist
# 7                   Data science instructor
# 8                     Junior Data Scientist
# 9                    Data Science Assistant
# 10                  Data Scientist (Junior)
# 11                            Data Engineer
# 12                           Data Scientist
# 13                    Junior Data Scientist
# 14          Data Science Analytics Deveoper
# 15                           Data Scientist
# 16                           Data Scientist
# 17                  Data Mentor (Part-time)
# 18          Data Science Associate (Remote)
# 19         Data Scientist - Personalization
# 20                   Advanced Data Engineer
# 21         Software Engineer - Data Science
# 22                           Data Scientist
# 23                            Data Engineer
# 24                 Instructor, Data Science
# 25                           Data Scientist
# 26                             Data Analyst
# 27          Data Scientist II - 100% Remote
# 28                           Data Scientist
# 29       Data Science and Signal Engineer I
#
#                           Company Name          Location      Salary Estimate  \
# 0                       Talentheed Inc            Remote  $100,000 /yr (est.)
# 1    Electric Power Research Institute     Charlotte, NC   $83,007 /yr (est.)
# 2                            CardWorks  South Jordan, UT  $134,452 /yr (est.)
# 3                   Moorecroft Systems            Remote    $52.50 /hr (est.)
# 4                        Dataquestcorp    Branchburg, NJ   $75,000 /yr (est.)
# 5   GTA (Global Technology Associates)     Englewood, CO   $80,000 /yr (est.)
# 6                   Myticas Consulting            Remote   $80,000 /yr (est.)
# 7                                  MIM            Remote  $131,513 /yr (est.)
# 8                               Augray    Brookfield, WI   $57,500 /yr (est.)
# 9                       United Nations      New York, NY   $88,585 /yr (est.)
# 10                                BDSA    Louisville, CO  $100,000 /yr (est.)
# 11                              Amazon            Remote  $275,000 /yr (est.)
# 12                        Infologitech            Remote    $85.00 /hr (est.)
# 13                               Acima        Draper, UT   $80,000 /yr (est.)
# 14                           Capgemini      New York, NY  $113,281 /yr (est.)
# 15               Openmind Technologies     Vacaville, CA    $57.50 /hr (est.)
# 16           3G Federal Solutions, LLC            Remote  $115,000 /yr (est.)
# 17                            Pathrise            Remote    $45.00 /hr (est.)
# 18                           pulseData      New York, NY   $59,834 /yr (est.)
# 19                             Audible        Newark, NJ   $85,503 /yr (est.)
# 20                              Kroger            Remote  $135,196 /yr (est.)
# 21                             Datadog      New York, NY  $120,117 /yr (est.)
# 22                     Motivated Leads            Remote  $240,000 /mo (est.)
# 23                         WALTLabs.io            Remote  $110,000 /yr (est.)
# 24       Bloom Institute of Technology            Remote  $110,000 /yr (est.)
# 25                        Sia Partners      New York, NY  $117,500 /yr (est.)
# 26                 Iver Solutions, LLC       Seattle, WA    $71.00 /hr (est.)
# 27                              Radian          Maryland  $123,648 /yr (est.)
# 28                           Dataworks            Remote  $122,500 /yr (est.)
# 29                           Medtronic    Northridge, CA  $122,500 /yr (est.)
#
#    Rating                                    Job Description  \
# 0      -1  Responsibilities:\nWork with stakeholders to d...
# 1     5.0  Job Title:\nStudent Employee - Data Science\nL...
# 2     3.1  Merrick Bank employees share in our mission to...
# 3      -1  Senior Data Science Engineer\nMoorecroft is lo...
# 4      -1  We are providing free training and placement o...
# 5     4.4  Looking for a Data Scientist III\nWhat you wil...
# 6     3.7  The recruitment team here at Myticas is lookin...
# 7      -1  ABOUT MIM\nMIM is a New York based institution...
# 8     4.3  Brookfield, WI, USA\nSummary:\nHiring Fresher ...
# 9     4.0  This position is located in the Analytics Sect...
# 10    1.4  Job Summary: The Analytics team empowers BDSA ...
# 11    3.8  BASIC QUALIFICATIONS\n5+ years of experience a...
# 12    4.3  Qualifications:\n-10+ years experience with R,...
# 13    3.7  ACIMA\nAcima Credit is a young and dynamic lea...
# 14    3.8  Data Science Analytics Developer\nFT Base+Bonu...
# 15     -1  Duration: 6 months\nJob Responsibilities inclu...
# 16     -1  Tasks (illustrative) – Forecasts and models to...
# 17    4.6  What is Pathrise?\nPathrise (YC W18) connects ...
# 18    5.0  pulseData is changing the way healthcare data ...
# 19    4.0  Job summary\nGood storytelling starts with gre...
# 20    3.1  POSITION SUMMARY\nAccountable for leading acti...
# 21    4.2  The Data Science team designs and builds algor...
# 22     -1  Data Scientist with Digital Space Experience\n...
# 23     -1  WALTLabs.io is looking for an experienced and ...
# 24    3.7  We started Bloom Institute of Technology becau...
# 25    4.0  Company Description\n\nSia Partners is a next-...
# 26    2.3  IBM/TikTok\nData Analyst\nLocation: Candidate ...
# 27    4.2  See yourself at Radian? We see you here too.\n...
# 28     -1  Data Scientist\nUnited States - Remote\nCompet...
# 29    4.1  Careers that Change Lives\nEngineers create ou...
#
#                       size            founded  \
# 0                       -1                 -1
# 1                  Unknown  Company - Private
# 2    501 to 1000 Employees               1987
# 3      51 to 200 Employees   Company - Public
# 4                       -1                 -1
# 5                  Unknown  Company - Private
# 6        1 to 50 Employees  Company - Private
# 7                       -1                 -1
# 8      51 to 200 Employees               2014
# 9         10000+ Employees               1945
# 10                 Unknown  Company - Private
# 11        10000+ Employees               1994
# 12       1 to 50 Employees  Company - Private
# 13   501 to 1000 Employees               2013
# 14        10000+ Employees               1967
# 15                      -1                 -1
# 16                 Unknown   Company - Public
# 17     51 to 200 Employees               2017
# 18       1 to 50 Employees               2015
# 19  1001 to 5000 Employees               1995
# 20        10000+ Employees   Company - Public
# 21  1001 to 5000 Employees               2010
# 22                      -1                 -1
# 23                      -1                 -1
# 24     51 to 200 Employees               2017
# 25  1001 to 5000 Employees               1999
# 26                 Unknown  Company - Private
# 27  1001 to 5000 Employees               1977
# 28       1 to 50 Employees               2021
# 29        10000+ Employees               1949
#
#                                        type  \
# 0                                        -1
# 1                  Unknown / Non-Applicable
# 2                         Company - Private
# 3                  Unknown / Non-Applicable
# 4                                        -1
# 5                  Unknown / Non-Applicable
# 6   Information Technology Support Services
# 7                                        -1
# 8            Subsidiary or Business Segment
# 9                                Government
# 10           Advertising & Public Relations
# 11                         Company - Public
# 12  Information Technology Support Services
# 13                         Company - Public
# 14                         Company - Public
# 15                                       -1
# 16                 Unknown / Non-Applicable
# 17                        Company - Private
# 18                        Company - Private
# 19           Subsidiary or Business Segment
# 20                           Grocery Stores
# 21                         Company - Public
# 22                                       -1
# 23                                       -1
# 24                        Company - Private
# 25                        Company - Private
# 26                 Unknown / Non-Applicable
# 27                         Company - Public
# 28                        Company - Private
# 29                         Company - Public
#
#                                    industry  \
# 0                                        -1
# 1                                        -1
# 2                         Banking & Lending
# 3                                        -1
# 4                                        -1
# 5                                        -1
# 6                    Information Technology
# 7                                        -1
# 8   Information Technology Support Services
# 9                         National Agencies
# 10                    Media & Communication
# 11                  Internet & Web Services
# 12                   Information Technology
# 13                        Banking & Lending
# 14  Enterprise Software & Network Solutions
# 15                                       -1
# 16                                       -1
# 17            Education & Training Services
# 18         Health Care Services & Hospitals
# 19                          Film Production
# 20                       Retail & Wholesale
# 21  Enterprise Software & Network Solutions
# 22                                       -1
# 23                                       -1
# 24            Education & Training Services
# 25                      Business Consulting
# 26                                       -1
# 27                       Insurance Carriers
# 28  Information Technology Support Services
# 29       Health Care Products Manufacturing
#
#                                 sector                     revenue
# 0                                   -1                          -1
# 1                                   -1                          -1
# 2                   Financial Services   $50 to $100 million (USD)
# 3                                   -1                          -1
# 4                                   -1                          -1
# 5                                   -1                          -1
# 6             Unknown / Non-Applicable                          -1
# 7                                   -1                          -1
# 8               Information Technology    Unknown / Non-Applicable
# 9   Government & Public Administration    Unknown / Non-Applicable
# 10            Unknown / Non-Applicable                          -1
# 11              Information Technology          $10+ billion (USD)
# 12              $1 to $5 million (USD)                          -1
# 13                  Financial Services    Unknown / Non-Applicable
# 14              Information Technology          $10+ billion (USD)
# 15                                  -1                          -1
# 16                                  -1                          -1
# 17                           Education      $1 to $5 million (USD)
# 18                          Healthcare    Unknown / Non-Applicable
# 19               Media & Communication    Unknown / Non-Applicable
# 20                  $10+ billion (USD)                          -1
# 21              Information Technology  $100 to $500 million (USD)
# 22                                  -1                          -1
# 23                                  -1                          -1
# 24                           Education    Unknown / Non-Applicable
# 25             Management & Consulting  $100 to $500 million (USD)
# 26                                  -1                          -1
# 27                           Insurance      $1 to $2 billion (USD)
# 28              Information Technology      $1 to $5 million (USD)
# 29                       Manufacturing          $10+ billion (USD)

# %%
trabajos_df[(trabajos_df["Location"] == "Remote") & (trabajos_df["Rating"] != -1) ]
# Out:
#                             Job Title                   Company Name Location  \
# 6   BHJOB15656_16794 - Data Scientist             Myticas Consulting   Remote
# 11                      Data Engineer                         Amazon   Remote
# 12                     Data Scientist                   Infologitech   Remote
# 17            Data Mentor (Part-time)                       Pathrise   Remote
# 20             Advanced Data Engineer                         Kroger   Remote
# 24           Instructor, Data Science  Bloom Institute of Technology   Remote
#
#         Salary Estimate Rating  \
# 6    $80,000 /yr (est.)    3.7
# 11  $275,000 /yr (est.)    3.8
# 12    $85.00 /hr (est.)    4.3
# 17    $45.00 /hr (est.)    4.6
# 20  $135,196 /yr (est.)    3.1
# 24  $110,000 /yr (est.)    3.7
#
#                                       Job Description                 size  \
# 6   The recruitment team here at Myticas is lookin...    1 to 50 Employees
# 11  BASIC QUALIFICATIONS\n5+ years of experience a...     10000+ Employees
# 12  Qualifications:\n-10+ years experience with R,...    1 to 50 Employees
# 17  What is Pathrise?\nPathrise (YC W18) connects ...  51 to 200 Employees
# 20  POSITION SUMMARY\nAccountable for leading acti...     10000+ Employees
# 24  We started Bloom Institute of Technology becau...  51 to 200 Employees
#
#               founded                                     type  \
# 6   Company - Private  Information Technology Support Services
# 11               1994                         Company - Public
# 12  Company - Private  Information Technology Support Services
# 17               2017                        Company - Private
# 20   Company - Public                           Grocery Stores
# 24               2017                        Company - Private
#
#                          industry                    sector  \
# 6          Information Technology  Unknown / Non-Applicable
# 11        Internet & Web Services    Information Technology
# 12         Information Technology    $1 to $5 million (USD)
# 17  Education & Training Services                 Education
# 20             Retail & Wholesale        $10+ billion (USD)
# 24  Education & Training Services                 Education
#
#                      revenue
# 6                         -1
# 11        $10+ billion (USD)
# 12                        -1
# 17    $1 to $5 million (USD)
# 20                        -1
# 24  Unknown / Non-Applicable
